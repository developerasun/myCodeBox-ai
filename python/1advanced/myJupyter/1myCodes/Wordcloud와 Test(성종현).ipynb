# %% [markdown]
# ## Wordcloud를 하기 위한 준비 단계

# %% [markdown]
# jdk 무료버전 설치
#  자바 다운로드 링크 https://www.oracle.com/java/technologies/javase-downloads.html
#  가입 후 jdk-8u202 버전 windows 또는 macOS 버전 받아 설치
#  내 pc 우측 마우스 클릭 --> 속성 --> 고급 시스템 설정 -->  환경 변수 --> 시스템 변수에서 새로 만들기 -->
#  변수 이름 : JAVA_HOME
#  변수 값 : 자바 설치한 디렉션 복사하여 붙여 넣기 예) C:\Program Files\Java\jdk1.8.0_202\bin
#  위의 값을 입력하고 모두 확인을 눌러서 나가기
#
# jpype 설치
#  아나콘다 프롬프트 관리자 권한으로 열어 pip install jpype1==1.1.2 또는 jpype1==0.7.0 설치
#
# konlpy와 wordcloud 설치
#  주피터 노트북에서 설치
#  pip install konlpy,
#  pip install wordcloud
#
# simplejson과 pytagcloud 설치
#  아나콘다 프롬프트에서 설치
#  pip install simplejson,
#  pip install pytagcloud,
#  pip install pygame
#
# 네이버에서 나눔고딕 다운을 받는다.
#
# 본인 컴퓨터에 설치된 pytagcloud폴더의 fonts 폴더로 NanumGothic.ttf 파일을 옮긴다.
# 예) C:\Users\USER\Anaconda3\Lib\site-packages\pytagcloud\fonts
#
# 폴더 안에 있는 fonts.json 파일을 연결프로그램을 눌러 메모장으로 연다.
# 아래와 같이 name에 korean, ttf에 NanumGothic.ttf, web에 http://fonts.googleapis.com/earlyaccess/nanumgothic.css 를 적어 저장한다.
# ![나눔고딕](나눔고딕.jpg)

# %% [markdown]
# 자바 다운로드 링크 https://www.oracle.com/java/technologies/javase-downloads.html

# %% [markdown]
# Jpype 다운로드 링크 https://www.lfd.uci.edu/~gohlke/pythonlibs/#jpype

# %%
from bs4 import BeautifulSoup 
import urllib.request 
from urllib.request import urlopen
from urllib.parse import quote
import pytagcloud
import re

from konlpy.tag import Okt
from collections import Counter

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %% [markdown]
# Wordcloud 할 링크 2개
#  1. 중앙일보 : 'https://news.joins.com/search/?keyword='
#  2. 동아닷컴 : https://www.donga.com/news/search?query="

# %%
nlp = Okt()

# %%
keyword = '고양이'
url = 'https://news.joins.com/search/?keyword='+ quote(keyword)
print(url)
# Out:
# https://news.joins.com/search/?keyword=%EA%B3%A0%EC%96%91%EC%9D%B4

# %%
quote(keyword)
# Out:
# '%EA%B3%A0%EC%96%91%EC%9D%B4'

# %%
html = urlopen(url)
html

# %%
# html5lib lxml html.parser
soup = BeautifulSoup(html.read(), 'html5lib', from_encoding = 'utf8')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html><head>
#         <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#         <meta charset="utf-8"/>
#         <meta content="width=device-width" name="viewport"/>
#         <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#         <meta content="upgrade-insecure-requests" http-equiv="Content-Security-Policy"/>
#         <meta content="고양이 통합 검색 결과 - 중앙일보" name="title"/>
#         <meta content="고양이 통합 검색 결과. 뉴스 검색, 동영상 검색, 이미지 검색, 인물 검색, 신문 지면 검색. 해적왕, 김종국, 남자 김종국, 대선배 김종국, 이후 김종국, e글중심, 윤봉길, 역사인식논란, 중앙일보, 중앙일보논설위원실, 최지혜인턴기자, 윤석열, 안중근" name="description"/>
#
#
#
#         <meta content="고양이 통합 검색 결과 - 중앙일보" name="twitter:title"/>
#         <meta content="no-referrer-when-downgrade" name="referrer"/>
#         <meta content="https://news.joins.com/search/?keyword=%ea%b3%a0%ec%96%91%ec%9d%b4" property="og:url"/>
#         <meta content="article" property="og:type"/>
#         <meta content="고양이 통합 검색 결과 - 중앙일보" property="og:title"/>
#         <meta content="고양이 통합 검색 결과. 뉴스 검색, 동영상 검색, 이미지 검색, 인물 검색, 신문 지면 검색. 해적왕, 김종국, 남자 김종국, 대선배 김종국, 이후 김종국, e글중심, 윤봉길, 역사인식논란, 중앙일보, 중앙일보논설위원실, 최지혜인턴기자, 윤석열, 안중근" property="og:description"/>
#         <meta content="https://static.joins.com/joongang_15re/profile_joongang_200.png" property="og:image"/>
#         <meta content="중앙일보" property="og:site_name"/>
#         <meta content="ko_KR" property="og:locale"/>
#         <meta content="https://www.joongang.co.kr" property="article:author"/>
#         <meta content="https://www.joongang.co.kr" property="article:publisher"/>
#         <title>고양이 통합 검색 결과 - 중앙일보</title>
#         <link href="https://news.joins.com/search/?keyword=%ea%b3%a0%ec%96%91%ec%9d%b4" rel="canonical"/>
#         <link href="https://images.joins.com/ui_mobile/joongang/icon/favicon.ico" rel="shortcut icon"/>
#         <link href="https://images.joins.com/ui_mobile/joongang/icon/ios_114.png" rel="apple-touch-icon-precomposed"/>
#         <link href="https://static.joins.com/joongang_15re/styles/pc/common.css" rel="stylesheet"/>
#         <link href="https://static.joins.com/joongang_15re/styles/pc/parent_v2.css" rel="stylesheet"/>
#         <link href="https://static.joins.com/joongang_15re/scripts/lib/jquery/ui/jquery-ui.min.css" rel="stylesheet"/>
#         <link href="https://static.joins.com/joongang_15re/scripts/lib/slick.css" rel="stylesheet"/>
#
#
#     <link href="https://static.joins.com/joongang_15re/styles/pc/search.css?20210819135937" rel="stylesheet"/>
#
#
#         <!-- Begin JA Tracker Script -->
#         <script type="text/javascript">
# 	    (function (jaW, jaD, jaS, jaG, jaR, jaA, jaM) {
# 		    jaW['JaTrackerObject'] = jaR;
# 		    jaW[jaR] = jaW[jaR] || function () {
# 			    (jaW[jaR].q = jaW[jaR].q || []).push(arguments);
# 		    }, jaW[jaR].l = 1 * new Date();
# 		    jaA = jaD.createElement(jaS),
# 		    jaM = jaD.getElementsByTagName(jaS)[0];
# 		    jaA.async = 1;
# 		    jaA.src = jaG;
# 		    jaM.parentNode.insertBefore(jaA, jaM);
# 	    })(window, document, 'script', '//jtrackern.joins.com/jatracker.min.js?v4', 'jatracker');
#         </script>
#         <!-- End JA Tracker Script -->
#
#         <!-- Begin Google Tag Manager Script -->
#         <script>
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window, document, 'script', 'dataLayer', 'GTM-PB3CHBW');
# var ga_dimension3 = 'Find';
#
#         </script>
#         <!-- End Google Tag Manager Script -->
#     </head>
#
#     <body class="aside_off searchwrap">
#         <input type="hidden" value=""/>
#         <!-- preLoad Image -->
#         <img alt="preLoad Image" class="preload" src="https://images.joins.com/ui_joongang/news/pc/common/k_nav_full_menu.png"/>
#         <img alt="preLoad Image" class="preload" src="https://images.joins.com/ui_joongang/news/pc/common/k_nav_cover.png"/>
#
#         <div class="joongang_skip">
#             <dl>
#                 <dd><a href="#searchArea"><span>검색 바로가기</span></a></dd>
#                 <dd><a href="#gnb_menu"><span>주메뉴 바로가기</span></a></dd>
#                 <dd><a href="#content"><span>주요 기사 바로가기</span></a></dd>
#                 <dd><a href="#sub"><span>다른 기사, 광고영역 바로가기</span></a></dd>
#                 <dd><a href="#footAllService"><span>중앙일보 사이트맵 바로가기</span></a></dd>
#             </dl>
#         </div>
#
#         <div class="doc">
#
#
# <input type="hidden" value=""/>
# <img alt="preLoad Image" class="preload" src="https://images.joins.com/ui_joongang/news/pc/common/k_nav_full_menu.png"/>
# <img alt="preLoad Image" class="preload" src="https://images.joins.com/ui_joongang/news/pc/common/k_nav_cover.png"/>
#
# <!-- skip navigation -->
# <div class="joongang_skip">
#     <dl>
#         <dd><a href="#searchArea"><span>검색 바로가기</span></a></dd>
#         <dd><a href="#gnb_menu"><span>주메뉴 바로가기</span></a></dd>
#         <dd><a href="#content"><span>주요 기사 바로가기</span></a></dd>
#         <dd><a href="#sub"><span>다른 기사, 광고영역 바로가기</span></a></dd>
#         <dd><a href="#footAllService"><span>중앙일보 사이트맵 바로가기</span></a></dd>
#     </dl>
# </div>
# <!-- //skip navigation -->
#
# <header class="header header_sub">
#     <div class="uh">
#
#
# <div class="joongang_logo">
#     <a href="https://joongang.joins.com?cloc=joongang-section-bi"><h2>중앙일보</h2></a><!-- 아티클에서는 h2 -->
# </div>
#
# <nav class="float_left">
#     <a class="btn_navbar" href="#none"><i class="icon_navbar">서비스 바로가기</i></a>
#
#         <!-- main_section -->
#         <div class="main_section">
#             <ul>
#                     <li>
#                         <a href="https://news.joins.com/opinion?cloc=joongang-section-gnb1">
#                             <h2 class="headline">오피니언</h2>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/politics?cloc=joongang-section-gnb2">
#                             <h2 class="headline">정치</h2>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/money?cloc=joongang-section-gnb3">
#                             <h2 class="headline">경제</h2>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/society?cloc=joongang-section-gnb4">
#                             <h2 class="headline">사회</h2>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/world?cloc=joongang-section-gnb5">
#                             <h2 class="headline">국제</h2>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/culture?cloc=joongang-section-gnb6">
#                             <h2 class="headline">문화</h2>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/sports?cloc=joongang-section-gnb7">
#                             <h2 class="headline">스포츠</h2>
#                         </a>
#                     </li>
#             </ul>
#         </div>
#         <!-- //main_section -->
# </nav>
#         <div class="float_right">
#             <div class="family_site">
#                 <a href="#none">중앙그룹 브랜드</a>
#             </div>
#             <div class="search_form">
#                 <a class="btn_search" href="https://joongang.joins.com"><i class="icon_search">검색</i></a>
#                 <div class="form_group">
#                     <label for="search1"><i class="icon_search">검색어</i></label>
#                     <input class="form_text" id="search1" placeholder="검색어를 입력하세요" type="text" value=""/>
#                 </div>
#             </div>
#             <div class="share_button">
#                 <a href="#none"><i class="icon_facebook">facebook</i></a>
#                 <a href="#none"><i class="icon_twitter">twitter</i></a>
#                 <a href="#none"><i class="icon_naver">naver</i></a>
#                 <a href="#none"><i class="icon_mail">mail</i></a>
#             </div>
#             <div class="member">
#                     <div class="login">
#                         <a class="btn_login" href="https://my.joins.com/login">로그인</a>
#                     </div>
#             </div>
#         </div>
#     </div>
#     <div class="mh">
#         <div class="search_wrap">
#     <div class="logo">
#         <h2 class="mg"><a href="https://joongang.joins.com">중앙일보</a></h2>
#     </div>
#     <div class="search" id="searchArea">
#         <fieldset>
#             <legend class="hide">검색</legend>
#             <label class="hide" for="search_word" style="visibility:visible;">뉴스검색</label>
#             <input autocomplete="off" class="txt mg" id="searchKeyword" style="cursor:initial" type="text" value="고양이"/>
#             <button class="btn" id="btnSearch" type="button">검색</button>
#         </fieldset>
#     </div>
# </div>
#
#     <nav class="lnb" id="joonganglnb">
#         <strong class="hide">검색 메인메뉴</strong>
#         <ul>
#                     <li class="on">
#                         <a href="https://news.joins.com/search?keyword=%ea%b3%a0%ec%96%91%ec%9d%b4">
#                             <h2 class="headline">
#                                 통합검색
#                             </h2>
#                         </a>
#                     </li>
#                     <li class="">
#                         <a href="https://news.joins.com/search/news?keyword=%ea%b3%a0%ec%96%91%ec%9d%b4">
#                             <h2 class="headline">
#                                 뉴스
#                             </h2>
#                         </a>
#                     </li>
#                     <li class="">
#                         <a href="https://news.joins.com/search/image?keyword=%ea%b3%a0%ec%96%91%ec%9d%b4">
#                             <h2 class="headline">
#                                 이미지
#                             </h2>
#                         </a>
#                     </li>
#                     <li class="">
#                         <a href="https://news.joins.com/search/video?keyword=%ea%b3%a0%ec%96%91%ec%9d%b4">
#                             <h2 class="headline">
#                                 동영상
#                             </h2>
#                         </a>
#                     </li>
#                     <li class="">
#                         <a href="https://news.joins.com/search/joins?keyword=%ea%b3%a0%ec%96%91%ec%9d%b4">
#                             <h2 class="headline">
#                                 조인스
#                                     <em>지면</em>
#                             </h2>
#                         </a>
#                     </li>
#                     <li class="">
#                         <a href="https://people.joins.com/Search/?pgi=1&amp;ps=&amp;q=%ea%b3%a0%ec%96%91%ec%9d%b4">
#                             <h2 class="headline">
#                                 인물
#                             </h2>
#                         </a>
#                     </li>
#
#         </ul>
#     </nav>
#
#     </div>
# </header>
#
#
#
# <div class="mega_menu" id="mega_menu">
#     <div class="hd">
#         <strong class="joongang_logo">
#         <a href="https://joongang.joins.com?cloc=joongang-section-megabi">중앙일보</a></strong>
#         <a class="btn_close" href="#mega_menu">
#             <i class="icon_close">닫기</i>
#         </a>
#     </div>
#
#     <div class="bd">
#                 <ul class="depth1">
#                     <li>
#                         <a href="https://news.joins.com/opinion?cloc=joongang-section-megatop" target="_self">
#                             <strong class="headline">오피니언</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/opinion/editorialcolumn/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">사설칼럼</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=SatiricalCartoon&amp;cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">만평</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/opinion/debate_polllist?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">Hot Poll</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=eTextCenter&amp;cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">e글중심</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/politics?cloc=joongang-section-megatop" target="_self">
#                             <strong class="headline">정치</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/politics/assemgov/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">국회정당</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/politics/bluehouse/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">청와대</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/politics/diplomacy/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">외교</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/politics/nk/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">국방</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/politics/northkorea/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">북한</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/money?cloc=joongang-section-megatop" target="_self">
#                             <strong class="headline">경제</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=EconomicPolicy&amp;cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">경제정책</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/money/indusrty/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">산업</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/money/finance/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">금융증권</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="http://realestate.joins.com/?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">부동산</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/money/science/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">과학미래</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/money/globaleconomy/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">글로벌경제</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/money/labor/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">고용노동</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/money/gmoney/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">글로벌머니</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/society?cloc=joongang-section-megatop" target="_self">
#                             <strong class="headline">사회</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/society/law/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">검찰·법원</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/society/education/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">교육</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/society/accident/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">사건사고</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/society/welfare/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">복지</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/society/traffic/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">교통</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/society/environment/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">환경</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/society/region/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">지역</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/society/health/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">건강</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/world?cloc=joongang-section-megatop" target="_self">
#                             <strong class="headline">국제</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/world/northame/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">미국</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/world/china/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">중국</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/world/japan/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">일본</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/world/eu/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">유럽</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/world/etc/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">기타</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/world/topic/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">토픽월드</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/culture?cloc=joongang-section-megatop" target="_self">
#                             <strong class="headline">문화</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/culture/book/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">책</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/culture/perfomance/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">공연</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/culture/art/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">미술</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/culture/classic/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">클래식</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/culture/song/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">가요</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/culture/broadcast/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">방송</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/culture/movie/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">영화</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/sports?cloc=joongang-section-megatop" target="_self">
#                             <strong class="headline">스포츠</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/sports/baseball/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">야구</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/sports/worldbaseball/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">해외야구</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/sports/soccer/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">축구</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/sports/worldsoccer/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">해외축구</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/sports/basketvolley/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">농구/배구</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/people?cloc=joongang-section-megatop" target="_self">
#                             <strong class="headline">피플</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/people/room/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">사랑방</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/people/personnel/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">인사</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/people/death/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">부음</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/lifestyle?cloc=joongang-section-megatop" target="_self">
#                             <strong class="headline">라이프 스타일</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/lifestyle/fashion/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">패션</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/lifestyle/taste/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">맛</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/lifestyle/luxury/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">럭셔리</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/lifestyle/beauty/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">뷰티</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/lifestyle/living/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">리빙</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/travel?cloc=joongang-section-megatop" target="_self">
#                             <strong class="headline">여행레저</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/travel/domestic/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">국내여행</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/travel/abroad/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">해외여행</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/travel/news/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">여행뉴스</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/travel/week/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">week&amp;</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/pic?cloc=joongang-section-megatop" target="_self">
#                             <strong class="headline">포토 · 영상</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/pic/photogallery/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">포토</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/pic/vod/list?cloc=joongang-section-megatop2depth" target="_self">
# 											<strong class="headline">영상</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                 </ul>
#                 <ul class="depth1">
#                     <li>
#                         <a href="https://news.joins.com/digitalspecial/list?cloc=joongang-section-megamiddle" target="_self">
#                             <strong class="headline">디지털 스페셜</strong>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/newsoneshot?cloc=joongang-section-megamiddle" target="_self">
#                             <strong class="headline">뉴스 ONESHOT</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=NewsOneShotPick&amp;cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">팀장의 픽</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=NewsOneShotChock&amp;cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">전문기자의 촉</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/sunday?cloc=joongang-section-megamiddle" target="_self">
#                             <strong class="headline">중앙SUNDAY</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/sunday/sundaynews/list?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">뉴스</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/sunday/sundaymoney/list?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">머니</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/sunday/sundayopinion/list?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">오피니언</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/sunday/sundaymagazine/list?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">S MAGAZINE</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/resetkorea?cloc=joongang-section-megamiddle" target="_self">
#                             <strong class="headline">리셋 코리아</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/article/21209278?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">리셋코리아 소개 </strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=ResetKoreaNews&amp;cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">뉴스</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/nk?cloc=joongang-section-megamiddle" target="_self">
#                             <strong class="headline">통일무지개</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/nk/odyssey/list?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">평양오디세이</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/nk/ing/list?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">북한~ing</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/nk/photolist?key=photo&amp;cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">사진 속 북한</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/retirement?cloc=joongang-section-megamiddle" target="_self">
#                             <strong class="headline">더,오래</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/retirement/cate?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">주제별</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/retirement/reporterlist?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">필진별</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/retirement/subscribe?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">필진 Pick</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/retirement/intro?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">더,오래란?</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://mgrg.joins.com/?cloc=joongang-section-megamiddle" target="_blank">
#                             <strong class="headline">먼지알지</strong>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://welfaretotal.joins.com/?cloc=joongang-section-megamiddle" target="_blank">
#                             <strong class="headline">복지토털</strong>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/mm?cloc=joongang-section-megamiddle" target="_self">
#                             <strong class="headline">Mr.밀리터리</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/mm/focusinside/list?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">Focus 인사이드</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/mm/hotnews/list?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">Hot 뉴스</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/mm/watchcon/list?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">김민석의 Watchcon</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/mm/weaponstory/list?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">무기이야기</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/mm/interview/list?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">김민석의 인터뷰</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="http://bbs.news.joins.com/mm/qna?cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">밀리터리 Request</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/jpod?cloc=joongang-section-megamiddle" target="_self">
#                             <strong class="headline">J팟</strong>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/cooking?cloc=joongang-section-megamiddle" target="_self">
#                             <strong class="headline">COOKING<span class="badge_new badge_sm">New</span></strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=CookingRecipe&amp;cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">레시피</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=CookingExpertInterview&amp;cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">인터뷰</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=CookingUserInterview&amp;cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">에세이</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=CookingClass&amp;cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">활용팁</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/minzireview?cloc=joongang-section-megamiddle" target="_self">
#                             <strong class="headline">minzi리뷰</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=MinziProduct&amp;cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">물건 Thing</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=MinziService&amp;cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">서비스 Service</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=MinziSpace&amp;cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">공간 Space</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=MinziCrew&amp;cloc=joongang-section-megamiddle2depth" target="_self">
# 											<strong class="headline">크루 Crew</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                 </ul>
#                 <ul class="depth1">
#                     <li>
#                         <a href="https://news.joins.com/newsletter?cloc=joongang-section-megabottom" target="_self">
#                             <strong class="headline">뉴스레터</strong>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/newsdigest?cloc=joongang-section-megabottom" target="_self">
#                             <strong class="headline">뉴스 다이제스트</strong>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/issue?cloc=joongang-section-megabottom" target="_self">
#                             <strong class="headline">이슈패키지</strong>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/trend?cloc=joongang-section-megabottom" target="_self">
#                             <strong class="headline">트렌드 뉴스</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/trend/daily?cloc=joongang-section-megabottom2depth" target="_self">
# 											<strong class="headline">실시간 트렌드</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/trend/weekly?cloc=joongang-section-megabottom2depth" target="_self">
# 											<strong class="headline">주간 트렌드 뉴스 </strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/trend/monthly?cloc=joongang-section-megabottom2depth" target="_self">
# 											<strong class="headline">월간 트렌드 뉴스 </strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/trend/tophistory?cloc=joongang-section-megabottom2depth" target="_self">
# 											<strong class="headline">지난 TOP 기사</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/reporter?cloc=joongang-section-megabottom" target="_self">
#                             <strong class="headline">기자</strong>
#                         </a>
#                     </li>
#                 </ul>
#                     <ul class="depth1">
# 									<li>
# 										<a href="https://news.joins.com/jebo?cloc=joongang-section-megaservice" target="_self">
# 											<strong class="headline">제보</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://jmembership.joins.com/?cloc=joongang-section-megaservice" target="_self">
# 											<strong class="headline">중앙멤버십</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/mynews?cloc=joongang-section-megaservice" target="_self">
# 											<strong class="headline">My뉴스</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/brandnews?cloc=joongang-section-megaservice" target="_self">
# 											<strong class="headline">보도 자료</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://people.joins.com/?cloc=joongang-section-megaservice" target="_self">
# 											<strong class="headline">인물 정보</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://www.joins.com/Media/List.aspx?mseq=11&amp;cloc=joongang-section-megaservice" target="_self">
# 											<strong class="headline">전자판</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://www.joins.com/Apply/Subscribe.aspx?cloc=joongang-section-megaservice" target="_self">
# 											<strong class="headline">지면 구독</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/customercenter?cloc=joongang-section-megaservice" target="_self">
# 											<strong class="headline">고객 센터</strong>
# 										</a>
# 									</li>
#                     </ul>
#
#     </div>
#
#     <div class="ft">
#         <i class="icon_godown"></i>
#     </div>
#
#     <a class="btn_close" href="javascript:;">닫기</a>
# </div>
#
# <!--중앙그룹 브랜드 메뉴-->
# <div class="layer_jmnet" id="layer_jmnet">
#     <div class="inner">
#         <ul class="">
#             <li>
#                 <strong class="">신문</strong>
#                 <ul>
#                     <li><a href="https://joongang.joins.com" target="_blank">중앙일보</a></li>
#                     <li><a href="https://news.joins.com/sunday" target="_blank">중앙SUNDAY</a></li>
#                     <li><a href="http://isplus.joins.com" target="_blank">일간스포츠</a></li>
#                     <li><a href="http://koreajoongangdaily.joins.com" target="_blank">Korea Joongang Daily</a></li>
#                     <li><a href="http://www.koreadaily.com/" target="_blank">The Korea Daily</a></li>
#                     <li><a href="https://sojoong.joins.com/" target="_blank">소년중앙</a></li>
#                     <li><a href="https://joind.io/" target="_blank">조인디</a></li>
#                 </ul>
#             </li>
#             <li>
#                 <strong class="">방송</strong>
#                 <ul>
#                     <li><a href="http://jtbc.joins.com" target="_blank">JTBC</a></li>
#                     <li><a href="http://jtbc2.joins.com" target="_blank">JTBC2</a></li>
#                     <li><a href="http://jtbcgolfnsports.joins.com/" target="_blank">JTBC GOLF&amp;SPORTS</a></li>
#                     <li><a href="http://jtbc4.joins.com/" target="_blank">JTBC4</a></li>
#                     <li><a href="http://www.jtbcgolf.com" target="_blank">JTBC GOLF</a></li>
#                     <li><a href="http://www.jtbcworldwide.com/" target="_blank">JTBC worldwide</a></li>
#                     <li><a href="https://jtbcmediatech.com/" target="_blank">JTBC미디어텍</a></li>
#                 </ul>
#             </li>
#             <li>
#                 <strong class="">멀티플렉스 &amp; 레저</strong>
#                 <ul>
#                     <li><a href="https://www.megabox.co.kr/" target="_blank">메가박스</a></li>
#                     <li><a href="https://www.megabox.co.kr/curation/filmsociety" target="_blank">필름 소사이어티</a></li>
#                     <li><a href="https://www.megabox.co.kr/curation/classicsociety" target="_blank">클래식 소사이어티</a></li>
#                     <li><a href="https://phoenixhnr.co.kr/page/main" target="_blank">휘닉스 호텔앤드리조트</a></li>
#                     <li><a href="https://phoenixhnr.co.kr/page/main/pyeongchang" target="_blank">휘닉스 평창</a></li>
#                     <li><a href="https://phoenixhnr.co.kr/page/main/jeju" target="_blank">휘닉스 섭지코지</a></li>
#                 </ul>
#             </li>
#             <li>
#                 <strong class="">매거진 &amp; 출판</strong>
#                 <div class="column2">
#                     <ul>
#                         <li><a href="https://jmagazine.joins.com/monthly" target="_blank">월간중앙</a></li>
#                         <li><a href="https://jmagazine.joins.com/economist" target="_blank">이코노미스트</a></li>
#                         <li><a href="https://jmagazine.joins.com/forbes" target="_blank">포브스코리아</a></li>
#                         <li><a href="https://jbooks.joins.com/" target="_blank">중앙북스</a></li>
#                     </ul>
#                     <ul>
#                         <li><a href="http://www.elle.co.kr/" target="_blank">엘르</a></li>
#                         <li><a href="http://harpersbazaar.co.kr/" target="_blank">바자</a></li>
#                         <li><a href="http://www.cosmopolitan.co.kr/" target="_blank">코스모폴리탄</a></li>
#                         <li><a href="http://esquirekorea.co.kr/" target="_blank">에스콰이어</a></li>
#                     </ul>
#                 </div>
#             </li>
#             <li>
#                 <strong class="">전문 콘텐트</strong>
#                 <ul>
#                     <li><a href="http://www.joinsland.com/" target="_blank">조인스랜드</a></li>
#                     <li><a href="http://www.jhealthmedia.com/" target="_blank">헬스미디어</a></li>
#                     <li><a href="https://blog.naver.com/china_lab" target="_blank">차이나랩</a></li>
#                     <li><a href="http://www.jdphone.com/" target="_blank">영어의 신</a></li>
#                     <li><a href="https://www.esukorea.org/" target="_blank">ESU</a></li>
#                 </ul>
#             </li>
#             <li>
#                 <strong class="">서비스</strong>
#                 <div class="column2">
#                     <ul>
#                         <li><a href="https://www.joins.com/" target="_blank">JOINS PRIME</a></li>
#                         <li><a href="https://ssully.joins.com/" target="_blank">썰리</a></li>
#                         <li><a href="https://folin.co/" target="_blank">fol:in</a></li>
#                         <li><a href="http://www.jtbcnow.com/" target="_blank">JTBC NOW</a></li>
#                         <li><a href="https://play.google.com/store/apps/details?id=com.jtbc.news" target="_blank">JTBC NEWS</a></li>
#                         <li><a href="http://oohmedia.kr/" target="_blank">OOH MEDIA</a></li>
#                     </ul>
#                     <ul>
#                         <li><a href="https://jmembership.joins.com/" target="_blank">중앙멤버십</a></li>
#                         <li><a href="http://sigol.joinsland.com/" target="_blank">렛츠고시골</a></li>
#                         <li><a href="http://tj4.joinsland.com/" target="_blank">TJ4대전충청</a></li>
#                     </ul>
#                 </div>
#             </li>
#         </ul>
#     </div>
#     <a class="btn_close" href="#"><i class="icon_close">닫기</i></a>
# </div>
# <!--// 중앙그룹 브랜드 메뉴-->
#             <div id="doc">
#                 <!-- 광고 728x90 -->
#                 <div class="ad_728_90 ad" id="articeltopbanner" style="display:none;"></div>
#                 <!-- //광고 728x90 -->
#                 <div id="wrap">
#                     <!-- 광고 120x200 -->
#                     <div class="ad_120_200 ad" id="leftbanner" style="display:none;"></div>
#                     <!-- //광고 120x200 -->
#                     <!-- 광고 300x250 -->
#                     <div class="ad_300_250 ad" id="shapepopup" style="display:none;"></div>
#                     <!-- //광고 300x250 -->
#                     <!-- 광고 1060x400 -->
#                     <div class="ad_1060_400 ad" style="display:none;"></div>
#                     <!-- //광고 1060x400 -->
#                     <!-- 광고 1060x90 -->
#                     <div class="ad_1060_90 ad" style="display:none;"></div>
#                     <!-- //광고 1060x90 -->
#
#
#                     <div id="body">
#
#
# <div id="sub">
#
# <!-- 검색 옵션 -->
# <div class="option_menu" id="search_filter">
#     <div class="hd">
#         <h3 class="hide">검색 옵션</h3>
#     </div>
#     <div class="bd">
#         <ul class="mg">
#             <li class="">
# ...
#         <script src="https://developers.kakao.com/sdk/js/kakao.min.js" type="text/javascript"></script>
#         <!--[if lte IE 9]>
#             <script src="https://static.joins.com/joongang_15re/scripts/lib/html5shiv.js"></script>
#             <script src="https://static.joins.com/joongang_15re/scripts/lib/respond.min.js"></script>
#             <script src="https://static.joins.com/joongang_15re/scripts/lib/json2.js"></script>
#             <script src="https://static.joins.com/joongang_15re/scripts/lib/jquery/jquery.xdomainrequest.js"></script>
#         <![endif]-->
#         <script src="https://static.joins.com/joongang_15re/scripts/utils/jquery.utils.js?20210819135937" type="text/javascript"></script>
#         <script src="https://static.joins.com/joongang_15re/scripts/utils/utils.js?20210819135937" type="text/javascript"></script>
#         <script type="text/javascript">
#             document.domain = "joins.com";
#             utils.config({
#                 'webPcPath': 'https://news.joins.com',
#                 'webMobilePath': 'https://mnews.joins.com',
#                 'staticPath': 'https://static.joins.com/joongang_15re',
#                 'imagePath': 'https://images.joins.com/ui_joongang/news',
#                 'apiPath': 'https://apis.joins.com',
#                 'irPath': 'https://ir.joins.com',
#                 'pdsPath': 'https://pds.joins.com',
#                 'jplusPath': 'http://jplus.joins.com',
#                 'searchWebPath': 'https://news.joins.com/search',
#                 'pageType': 'Search' || PAGE_TYPE.index,
#                 'articleType': '' || ARTICLE_TYPE.general
#             });
#
#
#
#         </script>
#         <script src="https://static.joins.com/joongang_15re/scripts/layout.js?20210819135937" type="text/javascript"></script>
#         <script src="https://static.joins.com/joongang_15re/scripts/layout.header.js?20210819135937" type="text/javascript"></script>
#         <script src="https://static.joins.com/joongang_15re/scripts/utils/widget.js?20210819135937" type="text/javascript"></script>
#         <script src="https://static.joins.com/joongang_15re/scripts/lib/slick.js" type="text/javascript"></script>
#         <script src="https://static.joins.com/joongang_15re/scripts/init.js?20210819135937" type="text/javascript"></script>
#         <script src="https://static.joins.com/joongang_15re/scripts/utils/mail.subscribe.v2.js"></script>
#
#
#
#         <script type="text/javascript">
#         $(function() {
#             var $frm = $('#FindFilter'),
#                 $startDate = $('#filterStartDate'),
#                 $endData = $('#filterEndDate'),
#                 serviceCodeOpen = utils.getCookie('serviceCodeOpen');
#
#             if(serviceCodeOpen == 'Y') {
#                 var $filaterArea = $("a[all-filter-item]", '#search_filter');
#                 $filaterArea.prev().each(function() {
#                     $(this).find('li').each(function() {
#                         var li = $(this);
#                         li.css('display', 'block');
#                     });
#                 });
#
#                 $filaterArea.html('접기<span class="icon"></span>');
#             }
#
#             $startDate.datepicker({
#                 showOn: 'button',
#                 buttonText: '날짜 선택',
#                 buttonImage: utils.config('imagePath') + "/pc/search/i_set_calendar.png",
#                 onClose: function(selectedDate) {
#                     $endData.datepicker("option", "minDate", selectedDate);
#                 }
#             });
#             $endData.datepicker({
#                 showOn: 'button',
#                 buttonText: '날짜 선택',
#                 buttonImage: utils.config('imagePath') + "/pc/search/i_set_calendar.png"
#             });
#
#             $('#btnSubmitForFilterDirectInput').on('click', function() {
#                 var type = $(this).data('type');
#
#                 if($startDate.val() == '' || $endData.val() == '') {
#                     return alert('검색하실 날짜 기간을 입력하세요.');
#                 }
#                 $('#StartSearchDate').val($startDate.val());
#                 $('#EndSearchDate').val($endData.val());
#                 $('#PeriodType').val(type);
#                 filterSearch();
#                 return false;
#             });
#
#             $("#btnSourceGroupType").on('click', function() {
#
#                 var $btn = $(this),
#                     $filterArea = $btn.closest('[filter-section]'),
#                     $checkedInput = $filterArea.find("input[type=checkbox]:checked"),
#                     sourceGroups = '',
#                     sourceCount = 0,
#                     newsCategoryArr = ["News", "JoongangNews", "JoongangSundayNews", "TotalNews"];
#
#                 $checkedInput.each(function (i, v) {
#                     if (sourceGroups.indexOf(v.value) < 0) {
#                         sourceGroups += ((i != 0 ? '|' : '') + v.value);
#                     }
#                     sourceCount++;
#                 });
#
#                 $('#SourceGroupType', $frm).val(sourceGroups);
#                 if($.inArray($('#SearchCategoryType').val(), newsCategoryArr) > -1) {
#                     if (sourceCount == 1 && sourceGroups == 'JoongangSunday') {
#                         $('#SearchCategoryType', $frm).val('JoongangSundayNews');
#                         $frm.attr('action', utils.config('searchWebPath') + '/JoongangSundayNews');
#                     } else if (sourceCount > 1 && sourceGroups.indexOf('JoongangSunday') > -1) {
#                         $('#SearchCategoryType', $frm).val('');
#                         $frm.attr('action', utils.config('searchWebPath') + '/news');
#                     } else {
#                         $('#SearchCategoryType', $frm).val('TotalNews');
#                         $frm.attr('action', utils.config('searchWebPath') + '/totalnews');
#                     }
#                 }
#
#                 filterSearch();
#                 return false;
#             });
#
#             $("a[all-filter-item]", '#search_filter').on('click', function() {
#                 var $btn = $(this),
#                     $filterArea = $btn.closest('[filter-section]'),
#                     $more = $filterArea.find(".more"),
#                     filterType = $btn.data('filterType');
#                 $btn.html($more.is(":hidden") ? '접기<span class="icon"></span>' : filterType + ' 전체보기<span class="icon"></span>');
#                 if($more.is(":hidden")) {
#                     utils.setCookie('serviceCodeOpen', 'Y', 1, COOKIE_CONDITION.path, COOKIE_CONDITION.domain);
#                 } else {
#                     utils.setCookie('serviceCodeOpen', 'N', 1, COOKIE_CONDITION.path, COOKIE_CONDITION.domain);
#                 }
#                 $more.toggle();
#                 return false;
#             });
#
#             $("#view_all").on('click', function() {
#                 var $btn = $(this),
#                     $filterArea = $btn.closest('[filter-section]'),
#                     $more = $filterArea.find(".more"),
#                     filterType = $btn.data('filterType');
#
#                 $btn.html($more.is(":hidden") ? '접기<span class="icon"></span>' : filterType + ' 전체보기<span class="icon"></span>');
#                 $more.toggle();
#                 return false;
#             });
#
#             $("#btnPreriodTypeDirectInput").on('click', function() {
#                 $("#searchPeriodArea").toggle();
#                 return false;
#             });
#
#             $("#searchPeriodClose").on('click', function() {
#                 var $layer = $(this).closest('.set_calendar');
#                 $layer.hide();
#             });
#
#             $('a[data-action=filterMore]', '#search_filter').on('click', function() {
#                 var $nextDiv = $(this).next();
#                 if($nextDiv.hasClass('search_area')) {
#                     $nextDiv.toggle();
#
#                     if($nextDiv.is(':visible') == true) {
#                         $(this).removeClass('toggle_off').addClass('toggle_on');
#                     } else {
#                         $(this).removeClass('toggle_on').addClass('toggle_off');
#                     }
#                 }
#                 return false;
#             });
#
#             function filterSearch() {
#                 $frm.submit();
#             }
#
#             $('#sourceGroupType00, #sourceGroupTypeCheck').checkGroup({
#                 list: '#filter_source_type',
#                 items: 'input[name=sourceGroupType]'
#             });
#
#             $('#related_keyword').widgetRelatedKeywordForSearch();
#             $('#popular_keyword').widgetPopularKeywordForSearch();
#
#             $('.view_related').relationArticles();
#         });
#     </script>
# <script type="text/javascript">
#         $(function() {
#
#             var $frm = $('#FindDetail');
#
#             $("#detailSearch").on('click', function() {
#                 var $this = $(this);
#                 $this.next().toggle();
#                 return false;
#             });
#
#             $("#detailSearchClose").on('click', function() {
#                 var $layer = $(this).closest('.layer_popup');
#                 $layer.hide();
#             });
#
#             $("#detailSearchSubmit").on('click', function() {
#
#                 if($("input[name=MatchKeyword]", $frm).val() == "" && $("input[name=IncludeKeyword]", $frm).val() == "" && $("input[name=ExcluedeKeyword]", $frm).val() == "") {
#                     alert("검색어를 입력해 주세요.");
#                     return false;
#                 }
#             });
#         });
#     </script>
# <script type="text/javascript">
# 		$(function () {
# 			reporterComponent.init();
# 		});
# 		var reporterComponent = {
# 			init: function () {
# 				this.jpicArticleSlideInit();
# 				this.issueSeriesSlideInit();
# 				this.anotherReporterInit();
# 			},
# 			jpicArticleSlideInit: function () {
# 				var jpicArticleSlide = $('.section_journalist .ranking .slide_wrap').slick({
# 					arrows: false,
# 					dots: true,
# 					infinite: true,
# 					swipe: false,
# 					fade: true,
# 					speed: 0,
# 					autoplay: true,
# 					autoplaySpeed: 9000,
# 					slidesToShow: 1,
# 					slidesToScroll: 1,
# 					customPaging: function (slider, i) {
# 						var title = $(slider.$slides[i]).data('title');
# 						return '<h3>' + title + '</h3>';
# 					}
# 				});
# 			},
# 			issueSeriesSlideInit: function () {
# 				var jpicCategorySlide = $('.journalist_star .slide_wrap').slick({
# 					arrows: true,
# 					dots: true,
# 					infinite: true,
# 					swipe: false,
# 					fade: true,
# 					speed: 0,
# 					slidesToShow: 1,
# 					slidesToScroll: 1,
# 					dotsClass: 'custom_paging',
# 					customPaging: function (slider, i) {
# 						if (slider.slideCount > 1) {
# 							return '<em>' + (i + 1) + '</em>' + '/' + slider.slideCount;
# 						}
# 					}
# 				});
# 			},
# 			anotherReporterInit: function () {
# 				var anotherReporterSlide = $('.relative_reporter .slide_wrap').slick({
# 					arrows: true,
# 					dots: false,
# 					infinite: false,
# 					//swipe:false,
# 					//fade: true,
# 					slidesToShow: 1,
# 					slidesToScroll: 1
# 				});
#
# 				$('.anotherReporterLink').on("click", function () {
# 					$.ajax({
# 						url: '/Search/Reporter',
# 						data: { "keyword": $("#searchKeyword").val(), "repSeq": $(this).data("id") },
# 						type: 'POST',
# 						success: function (data) {
# 							$('#search_reporter').html(data);
# 							reporterComponent.init();
# 						}
# 					});
# 				})
# 			}
# 		};
# 	</script>
# <script src="https://ssl.pstatic.net/adimg3.search/adpost/js/adpost_show_ads_v2.min.js" type="text/javascript"></script>
#     <script type="text/javascript">
# 		function handle_naver_ads_response(response) {
# 			var strAdPostHtml = "";
# 			var q = "고양이";
# 			try {
# 				if (response !== undefined && response.ads !== undefined && response.ads.length > 0) {
# 					strAdPostHtml += "<!-- 파워링크 -->";
# 					strAdPostHtml += "<div id=\"sponsor_list\" class=\"s_list powerlink\">";
# 					strAdPostHtml += "	<div class=\"hd head\">";
# 					strAdPostHtml += "		<strong>파워링크</strong>";
# 					strAdPostHtml += "	</div><!-- //hd -->";
# 					strAdPostHtml += "	<div class=\"bd\">";
# 					strAdPostHtml += "		<ul>";
# 					response.ads.forEach(function (item) {
# 						strAdPostHtml += "		<li>";
# 						strAdPostHtml += "			<dl>";
# 						strAdPostHtml += "			<dt><a href=\"" + item.clickUrl + "\" target=\"_blank\">" + item.headline.replace(q, "<strong>" + q + "</strong>") + "</a> </dt>";
# 						strAdPostHtml += "			<dd class=\"detail read_cr\"> - <a href=\"" + item.clickUrl + "\" target=\"_blank\">" + item.description.replace(q, "<strong>" + q + "</strong>") + "</a></dd>";
# 						strAdPostHtml += "			<dd class=\"url\"><a href=\"http://" + item.displayUrl + "\" target=\"_blank\"> " + item.displayUrl + "</a></dd>";
# 						strAdPostHtml += "			</dl>";
# 						strAdPostHtml += "		</li>";
# 					});
# 					strAdPostHtml += "		</ul>";
# 					strAdPostHtml += "	</div><!-- //bd -->";
# 					strAdPostHtml += "	<div class=\"ft\"><a href=\"http://saedu.naver.com/adbiz/searchad/intro.nhn\" class=\"add\" target=\"_blank\">등록 안내</a></div>";
# 					strAdPostHtml += "</div>";
# 					strAdPostHtml += "<!-- //파워링크 -->";
# 					$("#f_nhn_adpost_content").html(strAdPostHtml);
# 				}
# 			} catch (e) {}
# 		}
#
# 		var requestId;
# 		if (window.crypto && window.crypto.getRandomValues) {
# 			//requestId = ([1e7] + -1e3 + -4e3 + -8e3 + -1e11).replace(/[018]/g, c => (c ^ crypto.getRandomValues(new Uint8Array(1))[0] & 15 >> c / 4).toString(16));
# 			requestId = ([1e7] + -1e3 + -4e3 + -8e3 + -1e11).replace(/[018]/g, function (c) { return (c ^ crypto.getRandomValues(new Uint8Array(1))[0] & 15 >> c / 4).toString(16) });
# 		} else {
# 			requestId = 'xxxxxxxx-xxxx-4xxx-yxxx-xxxxxxxxxxxx'.replace(/[xy]/g, function (c) {
# 				var r = Math.random() * 16 | 0, v = c == 'x' ? r : (r & 0x3 | 0x8);
# 				return v.toString(16);
# 			});
# 		}
#
# 		NAVER_ADPOST_V2({
# 			requestId: requestId,
# 			channel: "joongang-joinsmsn.ch1",
# 			url: location.href,
# 			referrer: document.referrer,
# 			pageSize: 5,
# 			query: '고양이',
# 			test: false,
# 			mock: false
# 		});
#
#
#     </script>
#
# 		<!--  Begin GoogleAnalytics Addon Script -->
# 		<script type="text/javascript">
# 			/*jQuery(function ($) {
# 				var callBackTime = 100;
# 				var readerLocation = 150;
# 				var timer = 0;
# 				var scroller = false;
# 				var endContent = false;
# 				var didComplete = false;
# 				var startTime = new Date();
# 				var beginning = startTime.getTime();
# 				var totalTime = 0;
# 				var pageTitle = document.title;
# 				ga('send', 'event', 'Reading', 'NewsLoaded', pageTitle, { 'nonInteraction': 1 });
#
# 				function trackLocation() {
# 					bottom = $(window).height() + $(window).scrollTop();
# 					height = $(document).height();
# 					if (bottom > readerLocation && !scroller) {
# 						currentTime = new Date();
# 						scrollStart = currentTime.getTime();
# 						timeToScroll = Math.round((scrollStart - beginning) / 1000);
# 						ga('send', 'event', 'Reading', 'NewsStart', pageTitle, timeToScroll, { 'metric1': timeToScroll });
# 						scroller = true;
# 					}
#
# 					if (bottom >= $('#article_body').scrollTop() + $('#article_body').innerHeight() && !endContent) {
# 						currentTime = new Date();
# 						contentScrollEnd = currentTime.getTime();
# 						timeToContentEnd = Math.round((contentScrollEnd - scrollStart) / 1000);
# 						if (timeToContentEnd < 60) {
# 							ga('set', 'dimension11', 'FastReader');
# 						} else {
# 							ga('set', 'dimension11', 'SlowReader');
# 						}
# 						ga('send', 'event', 'Reading', 'NewsEnd', pageTitle, timeToContentEnd, { 'metric2': timeToContentEnd, 'metric4': 1 });
# 						endContent = true;
# 					}
#
# 					if (bottom >= height && !didComplete) {
# 						currentTime = new Date();
# 						end = currentTime.getTime();
# 						totalTime = Math.round((end - scrollStart) / 1000);
# 						ga('send', 'event', 'Reading', 'PageEnd', pageTitle, totalTime, { 'metric3': totalTime });
# 						didComplete = true;
# 					}
# 				}
#
# 				$(window).scroll(function () {
# 					if (timer) {
# 						clearTimeout(timer);
# 					}
# 					timer = setTimeout(trackLocation, callBackTime);
# 				});
# 			});*/
# 		</script>
# 		<!--  End GoogleAnalytics Addon Script -->
#
# </body></html>

# %%
i = 1 # 0~24까지 인덱스 범위 작동(중앙일보 기준) 
article_url = soup.findAll("a", {"href":re.compile("https://news.joins.com/article*")})[i]["href"] # * takes all types of args
article_url
# Out:
# 'https://news.joins.com/article/24131121'

# %%
# Open article and create soup2 

html2 = urlopen(article_url)
soup2 = BeautifulSoup(html2.read(), 'html5lib', from_encoding = 'utf8')
print(soup2)
# Out:
# <!DOCTYPE html>
# <!--[if IE]><![endif]--><!--[if lt IE 7 ]><html class="no-js ie6" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/" lang="ko" xml:lang="ko"><![endif]--><!--[if IE 7 ]><html class="no-js ie7" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/" lang="ko" xml:lang="ko"><![endif]--><!--[if IE 8 ]><html class="no-js ie8" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/" lang="ko" xml:lang="ko"><![endif]--><!--[if IE 9 ]><html class="no-js ie9" xmlns:fb="http://ogp.me/ns/fb#" lang="ko" xml:lang="ko"><![endif]--><!--[if (gt IE 9)|!(IE)]><!--><html class="no-js" lang="ko" xml:lang="ko" xmlns:fb="http://ogp.me/ns/fb#"><!--<![endif]--><head>
#     <title>'해적왕의 한 남자' 김종국 "에이티즈, 뭔가 다르다" 느꼈던 순간  - 중앙일보</title>
#     <meta charset="utf-8"/>
#     <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#     <meta content="width=device-width" name="viewport"/>
#     <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#     <meta content="upgrade-insecure-requests" http-equiv="Content-Security-Policy"/>
#     <meta content="'해적왕의 한 남자' 김종국 &quot;에이티즈, 뭔가 다르다&quot; 느꼈던 순간  - 중앙일보" name="title"/>
#     <meta content="지난 18일 오후 카카오TV를 통해 공개된 '해적왕의 한 남자'에는 컬래버 음원 '바다 보러 갈래?'를 위해 모인 에이티즈와 김종국의 모습이 담겼다. 김종국은 KBS 2TV '불후의 명곡'에서 보여준 에이티즈의 '검은 고양이' 무대에 대해 &quot;무대 하나로 끝나는 건데 준비를 너무 열심히 해준 게 고마웠고, 저렇게 할 수 있을까라 - 해적왕,김종국,남자 김종국,대선배 김종국,이후 김종국" name="description"/>
#     <meta content="해적왕,김종국,남자 김종국,대선배 김종국,이후 김종국" name="news_keywords"/>
#
#     <meta content="1011513095546498" property="fb:app_id"/>
#     <meta content="306376056509633" property="fb:pages"/>
#     <meta content="article" property="og:type"/>
#     <meta content="https://news.joins.com/article/24131121" property="og:url"/>
#     <meta content="'해적왕의 한 남자' 김종국 &quot;에이티즈, 뭔가 다르다&quot; 느꼈던 순간" property="og:title"/>
#     <meta content="지난 18일 오후 카카오TV를 통해 공개된 '해적왕의 한 남자'에는 컬래버 음원 '바다 보러 갈래?'를 위해 모인 에이티즈와 김종국의 모습이 담겼다. 김종국은 KBS 2TV '불후의 명곡'에서 보여준 에이티즈의 '검은 고양이' 무대에 대해 &quot;무대 하나로 끝나는 건데 준비를 너무 열심히 해준 게 고마웠고, 저렇게 할 수 있을까라" property="og:description"/>
#     <meta content="https://pds.joins.com/news/component/htmlphoto_mmdata/202108/19/89c298f9-521e-4322-acec-973697838d1c.jpg" property="og:image"/>
#     <meta content="중앙일보" property="og:site_name"/>
#     <meta content="ko_KR" property="og:locale"/>
#     <meta content="https://www.joongang.co.kr" property="article:author"/>
#     <meta content="https://www.joongang.co.kr" property="article:publisher"/>
#
#     <meta content="summary_large_image" name="twitter:card"/>
#     <meta content="'해적왕의 한 남자' 김종국 &quot;에이티즈, 뭔가 다르다&quot; 느꼈던 순간" name="twitter:title"/>
#     <meta content="지난 18일 오후 카카오TV를 통해 공개된 '해적왕의 한 남자'에는 컬래버 음원 '바다 보러 갈래?'를 위해 모인 에이티즈와 김종국의 모습이 담겼다. 김종국은 KBS 2TV '불후의 명곡'에서 보여준 에이티즈의 '검은 고양이' 무대에 대해 &quot;무대 하나로 끝나는 건데 준비를 너무 열심히 해준 게 고마웠고, 저렇게 할 수 있을까라" name="twitter:description"/>
#     <meta content="https://pds.joins.com/news/component/htmlphoto_mmdata/202108/19/89c298f9-521e-4322-acec-973697838d1c.jpg" name="twitter:image:src"/>
#     <meta content="no-referrer-when-downgrade" name="referrer"/>
#
#                     <meta content="연예" property="article:section"/>
#                 <meta content="연예일반" property="article:section2"/>
#                 <meta content="연예일반" property="article:section3"/>
#
#     <meta content="2021-08-19T08:38:28+09:00" property="article:published_time"/>
#
#
#
#
# <script src="https://static.joins.com/joongang_15re/scripts/utils/datalayer.js"></script>
# <script>
#     dataLayer = [{
#         'siteData': {
#             'hostName': 'news.joins.com'
#         },
#         'userData': {
#             'cid': '',
#             'uid': '',
#             'pcid': '',
#             'loginType': '',
#             'loginStatus': 'logout',
#             'userAgent': 'Python-urllib/3.8',
#             'membership': datalayerJS.RFV()
#         },
#         'pageData': {
#             'fullReferrer': '',
#             'hitTimestamp': '2021-08-19T13:59:41+09:00'
#         },
#         'contentData': {
#             'id': '24131121',
#             'primarySection': '연예',
#             'subSection': '연예일반',
#             'childSection': '연예|연예일반|연예일반',
#             'contentTags': '해적왕,김종국,남자 김종국,대선배 김종국,이후 김종국',
#             'contentUrl': 'https://news.joins.com/article/24131121',
#             'firstPublishedDate': '2021-08-19T08:38:28+09:00',
#             'lastUpdatedDate': '',
#             'authorName': '',
#             'authorDepartment': '',
#             'portalAuthorName': '',
#             'authorInfo': '',
#             'departmentInfo': '',
#             'contentTitle': '\'해적왕의 한 남자\' 김종국 "에이티즈, 뭔가 다르다" 느꼈던 순간',
#             'imageCheck': 'TRUE',
#             'numImageCheck': '1',
#             'videoCheck': 'FALSE',
#             'contentType': 'General',
#             'articleTemplate': 'General',
#             'contentSourceName': '일간스포츠',
#             'contentSourceCode': '29',
#             'contentsWordCount': '889',
#             'jamAarticleType': '02',
#             'bulk': ''
#         }
#     }];
# </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window, document, 'script', 'dataLayer','GTM-NGGTPFC');</script>
# <!-- End Google Tag Manager -->
#
# <!-- Begin JA Tracker Script -->
# <script type="text/javascript">
#     (function (jaW, jaD, jaS, jaG, jaR, jaA, jaM) {
#         jaW['JaTrackerObject'] = jaR;
#         jaW[jaR] = jaW[jaR] || function () {
#             (jaW[jaR].q = jaW[jaR].q || []).push(arguments);
#         }, jaW[jaR].l = 1 * new Date();
#         jaA = jaD.createElement(jaS),
#             jaM = jaD.getElementsByTagName(jaS)[0];
#         jaA.async = 1;
#         jaA.src = jaG;
#         jaM.parentNode.insertBefore(jaA, jaM);
#     })(window, document, 'script', '//jtrackern.joins.com/jatracker.min.js?v4', 'jatracker');
# </script>
# <!-- End JA Tracker Script -->
#
# <script type="text/javascript">
#     window._taboola = window._taboola || [];
#     _taboola.push({ article: 'auto' });
#     !function (e, f, u, i) {
#         if (!document.getElementById(i)) {
#             e.async = 1;
#             e.src = u;
#             e.id = i;
#             f.parentNode.insertBefore(e, f);
#         }
#     }(document.createElement('script'),
#         document.getElementsByTagName('script')[0],
#         '//cdn.taboola.com/libtrc/joongang-desktop/loader.js',
#         'tb_loader_script');
#     if (window.performance && typeof window.performance.mark == 'function') { window.performance.mark('tbl_ic'); }
# </script>
#
#
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
#
#     <script>
#         window.googletag = window.googletag || { cmd: [] };
#         googletag.cmd.push(function () {
#                     googleAdActive('/30349040/JA_PC_article/JA_PC_article_standard/standard_top/728x90', [728, 90], 'div-gpt-ad-1616486235400-0');
#                     googleAdActive('/30349040/JA_PC_article/JA_PC_article_standard/standard_mid/250x250', [250, 250], 'div-gpt-ad-1617179927787-0');
#                     googleAdActive('/30349040/JA_PC_article/JA_PC_article_standard/standard_bottom/300x600', [300, 600], 'div-gpt-ad-1616486854448-0');
#                     googleAdActive('/30349040/JA_PC_article/JA_PC_article_standard/standard_bottom/250x250', [[300, 250], [250, 250]], 'div-gpt-ad-1616487006166-0');
#                     googleAdActive('/30349040/JA_PC_article/JA_PC_article_standard/standard_bottom/300x250', [300, 250], 'div-gpt-ad-1616487046295-0');
#                     googleAdActive('/30349040/JA_PC_article/JA_PC_article_standard/standard_top/120x600', [120, 600], 'div-gpt-ad-1616486320825-0');
#                     googleAdActive('/30349040/JA_PC_article/JA_PC_article_standard/standard_top/300x250', [300, 250], 'div-gpt-ad-1616486482963-0');
#         });
#
#         function googleAdActive(url, size, id) {
#             googletag.defineSlot(url, size, id).addService(googletag.pubads());
#             googletag.pubads().enableSingleRequest();
#             googletag.pubads().collapseEmptyDivs();
#             googletag.enableServices();
#         }
#     </script>
#
#
#     <link href="https://images.joins.com/ui_mobile/joongang/icon/favicon.ico" rel="shortcut icon"/>
#                 <link href="https://news.joins.com/article/24131121" rel="alternate"/>
#
#     <script type="application/ld+json">
#         {
#         "@context": "http://schema.org",
#         "@type": "WebSite",
#         "@id": "https://joongang.joins.com",
#         "url": "https://joongang.joins.com",
#         "potentialAction": [{
#         "@type": "SearchAction",
#         "target": "https://news.joins.com/search/JoongangNews?keyword={keyword}",
#         "query-input": {
#         "@type": "PropertyValueSpecification",
#         "valueRequired": true,
#         "valueMaxlength": 50,
#         "valueName": "keyword"
#         }
#         }]
#         }
#     </script>
#                 <script type="application/ld+json">
#                     {
#                     "@context": "http://schema.org",
#                     "@type": "NewsArticle",
#                     "@id": "https://news.joins.com/article/24131121",
#                     "mainEntityOfPage":{
#                     "@type":"WebPage",
#                     "@id":"https://news.joins.com/article/24131121"
#                     },
#                     "headline": "&#39;해적왕의 한 남자&#39; 김종국 &amp;#34;에이티즈, 뭔가 다르다&amp;#34; 느꼈던 순간  - 중앙일보",
#                     "image": {
#                     "@type": "ImageObject",
#                     "@id": "https://pds.joins.com/news/component/htmlphoto_mmdata/202108/19/89c298f9-521e-4322-acec-973697838d1c.jpg",
#                     "url": "https://pds.joins.com/news/component/htmlphoto_mmdata/202108/19/89c298f9-521e-4322-acec-973697838d1c.jpg",
#                     "height": 450,
#                     "width": 800
#                     },
#                     "datePublished": "2021-08-19T08:38:28+09:00",
#                     "dateModified": "2021-08-19T08:38:28+09:00",
#                     "author": {
#                     "@type": "Organization",
#                     "name": "중앙일보"
#                     },
#                     "publisher": {
#                     "@type": "Organization",
#                     "@id": "https://joongang.joins.com",
#                     "name": "중앙일보",
#                     "logo": {
#                     "@type": "ImageObject",
#                     "url": "https://images.joins.com/logo/logo_joongangilbo.png",
#                     "width": 160
#                     },
#                     "sameAs":["https://www.facebook.com/joongang","https://twitter.com/joongangilbo"]
#                     },
#                     "description": "지난 18일 오후 카카오TV를 통해 공개된 '해적왕의 한 남자'에는 컬래버 음원 '바다 보러 갈래?'를 위해 모인 에이티즈와 김종국의 모습이 담겼다. 김종국은 KBS 2TV '불후의 명곡'에서 보여준 에이티즈의 '검은 고양이' 무대에 대해 &#34;무대 하나로 끝나는 건데 준비를 너무 열심히 해준 게 고마웠고, 저렇게 할 수 있을까라 - 해적왕,김종국,남자 김종국,대선배 김종국,이후 김종국"
#                     }
#                 </script>
#
#     <link href="https://images.joins.com/ui_mobile/joongang/icon/ios_114.png" rel="apple-touch-icon-precomposed"/>
#     <link href="https://static.joins.com/joongang_15re/styles/pc/parent_v2.css?20210808" rel="stylesheet"/>
#     <link href="https://static.joins.com/joongang_15re/styles/pc/common.css?20210808" rel="stylesheet"/>
#
#
#
#         <link href="https://static.joins.com/joongang_15re/scripts/lib/slick.css" rel="stylesheet"/>
#
#
#
#     <link href="https://static.joins.com/joongang_15re/scripts/lib/jquery/ui/jquery-ui.min.css" rel="stylesheet"/>
#     <link href="https://news.joins.com/article/24131121" rel="canonical"/>
#
#
#     <link href="https://static.joins.com/joongang_15re/styles/pc/article.css?20210808" rel="stylesheet"/>
#     <link href="https://static.joins.com/joongang_15re/styles/pc/article_cmt.css?20210808" rel="stylesheet"/>
#
#     <link href="https://mnews.joins.com/article/24131121" media="only screen and (max-width: 640px)" rel="alternate"/>
#     <link href="https://mnews.joins.com/article/24131121" media="handheld" rel="alternate"/>
#
#
#
#
#     <script async="" src="//cast.imp.joins.com/persona.js"></script>
# </head>
#
# <body class="aside_on">
#     <input type="hidden" value=""/>
#     <!-- preLoad Image -->
#     <img alt="preLoad Image" class="preload" src="https://images.joins.com/ui_joongang/news/pc/common/k_nav_full_menu.png"/>
#     <img alt="preLoad Image" class="preload" src="https://images.joins.com/ui_joongang/news/pc/common/k_nav_cover.png"/>
#
#     <!-- skip navigation -->
#     <div class="joongang_skip">
#         <dl>
#             <dd><a href="#searchArea"><span>검색 바로가기</span></a></dd>
#             <dd><a href="#gnb_menu"><span>주메뉴 바로가기</span></a></dd>
#             <dd><a href="#content"><span>주요 기사 바로가기</span></a></dd>
#             <dd><a href="#sub"><span>다른 기사, 광고영역 바로가기</span></a></dd>
#             <dd><a href="#footAllService"><span>중앙일보 사이트맵 바로가기</span></a></dd>
#         </dl>
#     </div>
#     <!-- //skip navigation -->
#
#
#         <!-- 광고 728x90 -->
#         <div class="container_fluid premium_richmedia ad_top">
#             <div class="ad_728_90 ad" id="articeltopbanner"></div>
#         </div>
#         <!-- //광고 728x90 -->
#
#     <div class="doc">
#
#
# <header class="header header_sub">
#     <div class="uh">
#
#
# <div class="joongang_logo">
#     <a href="https://joongang.joins.com?cloc=joongang-article-bi"><h2>중앙일보</h2></a><!-- 아티클에서는 h2 -->
# </div>
#
# <nav class="float_left">
#     <a class="btn_navbar" href="#none"><i class="icon_navbar">서비스 바로가기</i></a>
#     <!-- 통합검색-->
#     <div class="search_area">
#         <!-- search_on -->
#         <a class="btn_search_area" href="#layer_search_area"><i class="icon_search">검색</i></a>
#         <div class="layer_search_area" id="layer_search_area" style="display: none;" tabindex="0">
#             <button class="btn_close" type="button"><i class="icon_close">닫기</i></button>
#             <div class="inner" id="searchArea">
#                 <button class="btn_close" type="button"><i class="icon_close">닫기</i></button>
#                 <div class="form_group">
#                     <label class="sr_only" for="searchKeyword">검색어</label>
#                     <input class="form_text" id="searchKeyword" placeholder="검색어를 입력하세요" type="text" value=""/>
#                     <button class="btn_search" id="btnSearch" type="submit">검색</button>
#                 </div>
#             </div>
#         </div>
#     </div>
#     <!--// 통합검색-->
#
#             <div class="main_section">
#                 <ul>
#                         <li>
#                             <a href="https://news.joins.com/opinion?cloc=joongang-article-gnb1">
#                                 <h2 class="headline">오피니언</h2>
#                             </a>
#                         </li>
#                         <li>
#                             <a href="https://news.joins.com/politics?cloc=joongang-article-gnb2">
#                                 <h2 class="headline">정치</h2>
#                             </a>
#                         </li>
#                         <li>
#                             <a href="https://news.joins.com/money?cloc=joongang-article-gnb3">
#                                 <h2 class="headline">경제</h2>
#                             </a>
#                         </li>
#                         <li>
#                             <a href="https://news.joins.com/society?cloc=joongang-article-gnb4">
#                                 <h2 class="headline">사회</h2>
#                             </a>
#                         </li>
#                         <li>
#                             <a href="https://news.joins.com/world?cloc=joongang-article-gnb5">
#                                 <h2 class="headline">국제</h2>
#                             </a>
#                         </li>
#                         <li>
#                             <a href="https://news.joins.com/culture?cloc=joongang-article-gnb6">
#                                 <h2 class="headline">문화</h2>
#                             </a>
#                         </li>
#                         <li>
#                             <a href="https://news.joins.com/sports?cloc=joongang-article-gnb7">
#                                 <h2 class="headline">스포츠</h2>
#                             </a>
#                         </li>
#                 </ul>
#             </div>
# </nav>
#         <div class="float_right">
#
# <span></span>
#
# <div class="family_site">
#     <a href="#layer_jmnet">중앙그룹 브랜드</a>
# </div>
# <div class="share_button">
#         <a data-bind="btn" data-id="24131121" data-service="kakaotalk" data-target="news" href="#none" target="_blank" title="(새창) 카카오톡 공유"><i class="icon_kakaotalk">kakaotalk</i></a>
#         <a data-bind="btn" data-id="24131121" data-service="facebook" data-target="news" href="#none" target="_blank" title="(새창) 페이스북 공유"><i class="icon_facebook">facebook</i></a>
#         <a data-bind="btn" data-id="24131121" data-service="twitter" data-target="news" href="#none" target="_blank" title="(새창) 트위터 공유"><i class="icon_twitter">twitter</i></a>
#         <a data-bind="btn" data-id="24131121" data-service="email" data-target="news" href="#none" target="_blank" title="(새창) 메일 공유"><i class="icon_mail">mail</i></a>
# </div>
# <div class="member">
#             <div class="login">
#                 <a class="btn_login" href="https://my.joins.com/login">로그인</a>
#             </div>
# </div>
#         </div>
#     </div>
#                 <div class="mh">
#
#
#     <div class="logo_service">
#         <h2 class="service">
#                     <a href="https://news.joins.com/culture?cloc=joongang-article-sectiontitle" target="_self">문화</a>
#         </h2>
#     </div>
#     <!-- 서비스 메인메뉴 -->
#     <nav class="lnb" id="joonganglnb">
#         <strong class="hide">문화 메인메뉴</strong>
#         <ul>
# 						<li class="">
# 							<a href="https://news.joins.com/culture/book/list?cloc=joongang-article-subsection" target="_self">
# 								<h2 class="headline">
# 								책
# 								</h2>
# 							</a>
# 						</li>
# 						<li class="">
# 							<a href="https://news.joins.com/culture/perfomance/list?cloc=joongang-article-subsection" target="_self">
# 								<h2 class="headline">
# 								공연
# 								</h2>
# 							</a>
# 						</li>
# 						<li class="">
# 							<a href="https://news.joins.com/culture/art/list?cloc=joongang-article-subsection" target="_self">
# 								<h2 class="headline">
# 								미술
# 								</h2>
# 							</a>
# 						</li>
# 						<li class="">
# 							<a href="https://news.joins.com/culture/classic/list?cloc=joongang-article-subsection" target="_self">
# 								<h2 class="headline">
# 								클래식
# 								</h2>
# 							</a>
# 						</li>
# 						<li class="">
# 							<a href="https://news.joins.com/culture/song/list?cloc=joongang-article-subsection" target="_self">
# 								<h2 class="headline">
# 								가요
# 								</h2>
# 							</a>
# 						</li>
# 						<li class="on">
# 							<a href="https://news.joins.com/culture/broadcast/list?cloc=joongang-article-subsection" target="_self">
# 								<h2 class="headline">
# 								방송
# 								</h2>
# 							</a>
# 						</li>
# 						<li class="">
# 							<a href="https://news.joins.com/culture/movie/list?cloc=joongang-article-subsection" target="_self">
# 								<h2 class="headline">
# 								영화
# 								</h2>
# 							</a>
# 						</li>
#         </ul>
#     </nav>
#     <!-- //서비스 메인메뉴 -->
#
#                 </div>
#
# </header>
#
#
#
# <div class="mega_menu" id="mega_menu">
#     <div class="hd">
#         <strong class="joongang_logo">
#         <a href="https://joongang.joins.com?cloc=joongang-article-megabi">중앙일보</a></strong>
#         <a class="btn_close" href="#mega_menu">
#             <i class="icon_close">닫기</i>
#         </a>
#     </div>
#
#     <div class="bd">
#                 <ul class="depth1">
#                     <li>
#                         <a href="https://news.joins.com/opinion?cloc=joongang-article-megatop" target="_self">
#                             <strong class="headline">오피니언</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/opinion/editorialcolumn/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">사설칼럼</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=SatiricalCartoon&amp;cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">만평</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/opinion/debate_polllist?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">Hot Poll</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=eTextCenter&amp;cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">e글중심</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/politics?cloc=joongang-article-megatop" target="_self">
#                             <strong class="headline">정치</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/politics/assemgov/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">국회정당</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/politics/bluehouse/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">청와대</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/politics/diplomacy/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">외교</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/politics/nk/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">국방</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/politics/northkorea/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">북한</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/money?cloc=joongang-article-megatop" target="_self">
#                             <strong class="headline">경제</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=EconomicPolicy&amp;cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">경제정책</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/money/indusrty/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">산업</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/money/finance/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">금융증권</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="http://realestate.joins.com/?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">부동산</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/money/science/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">과학미래</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/money/globaleconomy/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">글로벌경제</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/money/labor/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">고용노동</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/money/gmoney/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">글로벌머니</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/society?cloc=joongang-article-megatop" target="_self">
#                             <strong class="headline">사회</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/society/law/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">검찰·법원</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/society/education/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">교육</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/society/accident/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">사건사고</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/society/welfare/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">복지</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/society/traffic/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">교통</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/society/environment/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">환경</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/society/region/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">지역</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/society/health/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">건강</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/world?cloc=joongang-article-megatop" target="_self">
#                             <strong class="headline">국제</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/world/northame/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">미국</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/world/china/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">중국</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/world/japan/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">일본</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/world/eu/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">유럽</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/world/etc/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">기타</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/world/topic/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">토픽월드</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/culture?cloc=joongang-article-megatop" target="_self">
#                             <strong class="headline">문화</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/culture/book/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">책</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/culture/perfomance/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">공연</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/culture/art/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">미술</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/culture/classic/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">클래식</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/culture/song/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">가요</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/culture/broadcast/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">방송</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/culture/movie/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">영화</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/sports?cloc=joongang-article-megatop" target="_self">
#                             <strong class="headline">스포츠</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/sports/baseball/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">야구</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/sports/worldbaseball/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">해외야구</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/sports/soccer/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">축구</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/sports/worldsoccer/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">해외축구</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/sports/basketvolley/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">농구/배구</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/people?cloc=joongang-article-megatop" target="_self">
#                             <strong class="headline">피플</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/people/room/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">사랑방</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/people/personnel/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">인사</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/people/death/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">부음</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/lifestyle?cloc=joongang-article-megatop" target="_self">
#                             <strong class="headline">라이프 스타일</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/lifestyle/fashion/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">패션</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/lifestyle/taste/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">맛</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/lifestyle/luxury/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">럭셔리</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/lifestyle/beauty/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">뷰티</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/lifestyle/living/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">리빙</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/travel?cloc=joongang-article-megatop" target="_self">
#                             <strong class="headline">여행레저</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/travel/domestic/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">국내여행</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/travel/abroad/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">해외여행</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/travel/news/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">여행뉴스</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/travel/week/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">week&amp;</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/pic?cloc=joongang-article-megatop" target="_self">
#                             <strong class="headline">포토 · 영상</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/pic/photogallery/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">포토</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/pic/vod/list?cloc=joongang-article-megatop2depth" target="_self">
# 											<strong class="headline">영상</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                 </ul>
#                 <ul class="depth1">
#                     <li>
#                         <a href="https://news.joins.com/digitalspecial/list?cloc=joongang-article-megamiddle" target="_self">
#                             <strong class="headline">디지털 스페셜</strong>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/newsoneshot?cloc=joongang-article-megamiddle" target="_self">
#                             <strong class="headline">뉴스 ONESHOT</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=NewsOneShotPick&amp;cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">팀장의 픽</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=NewsOneShotChock&amp;cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">전문기자의 촉</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/sunday?cloc=joongang-article-megamiddle" target="_self">
#                             <strong class="headline">중앙SUNDAY</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/sunday/sundaynews/list?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">뉴스</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/sunday/sundaymoney/list?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">머니</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/sunday/sundayopinion/list?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">오피니언</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/sunday/sundaymagazine/list?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">S MAGAZINE</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/resetkorea?cloc=joongang-article-megamiddle" target="_self">
#                             <strong class="headline">리셋 코리아</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/article/21209278?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">리셋코리아 소개 </strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=ResetKoreaNews&amp;cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">뉴스</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/nk?cloc=joongang-article-megamiddle" target="_self">
#                             <strong class="headline">통일무지개</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/nk/odyssey/list?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">평양오디세이</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/nk/ing/list?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">북한~ing</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/nk/photolist?key=photo&amp;cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">사진 속 북한</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/retirement?cloc=joongang-article-megamiddle" target="_self">
#                             <strong class="headline">더,오래</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/retirement/cate?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">주제별</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/retirement/reporterlist?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">필진별</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/retirement/subscribe?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">필진 Pick</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/retirement/intro?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">더,오래란?</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://mgrg.joins.com/?cloc=joongang-article-megamiddle" target="_blank">
#                             <strong class="headline">먼지알지</strong>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://welfaretotal.joins.com/?cloc=joongang-article-megamiddle" target="_blank">
#                             <strong class="headline">복지토털</strong>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/mm?cloc=joongang-article-megamiddle" target="_self">
#                             <strong class="headline">Mr.밀리터리</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/mm/focusinside/list?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">Focus 인사이드</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/mm/hotnews/list?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">Hot 뉴스</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/mm/watchcon/list?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">김민석의 Watchcon</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/mm/weaponstory/list?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">무기이야기</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/mm/interview/list?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">김민석의 인터뷰</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="http://bbs.news.joins.com/mm/qna?cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">밀리터리 Request</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/jpod?cloc=joongang-article-megamiddle" target="_self">
#                             <strong class="headline">J팟</strong>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/cooking?cloc=joongang-article-megamiddle" target="_self">
#                             <strong class="headline">COOKING<span class="badge_new badge_sm">New</span></strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=CookingRecipe&amp;cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">레시피</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=CookingExpertInterview&amp;cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">인터뷰</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=CookingUserInterview&amp;cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">에세이</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=CookingClass&amp;cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">활용팁</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/minzireview?cloc=joongang-article-megamiddle" target="_self">
#                             <strong class="headline">minzi리뷰</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=MinziProduct&amp;cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">물건 Thing</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=MinziService&amp;cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">서비스 Service</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=MinziSpace&amp;cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">공간 Space</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/find/list?key=MinziCrew&amp;cloc=joongang-article-megamiddle2depth" target="_self">
# 											<strong class="headline">크루 Crew</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                 </ul>
#                 <ul class="depth1">
#                     <li>
#                         <a href="https://news.joins.com/newsletter?cloc=joongang-article-megabottom" target="_self">
#                             <strong class="headline">뉴스레터</strong>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/newsdigest?cloc=joongang-article-megabottom" target="_self">
#                             <strong class="headline">뉴스 다이제스트</strong>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/issue?cloc=joongang-article-megabottom" target="_self">
#                             <strong class="headline">이슈패키지</strong>
#                         </a>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/trend?cloc=joongang-article-megabottom" target="_self">
#                             <strong class="headline">트렌드 뉴스</strong>
#                         </a>
#                         <ul class="depth2">
# 									<li>
# 										<a href="https://news.joins.com/trend/daily?cloc=joongang-article-megabottom2depth" target="_self">
# 											<strong class="headline">실시간 트렌드</strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/trend/weekly?cloc=joongang-article-megabottom2depth" target="_self">
# 											<strong class="headline">주간 트렌드 뉴스 </strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/trend/monthly?cloc=joongang-article-megabottom2depth" target="_self">
# 											<strong class="headline">월간 트렌드 뉴스 </strong>
# 										</a>
# 									</li>
# 									<li>
# 										<a href="https://news.joins.com/trend/tophistory?cloc=joongang-article-megabottom2depth" target="_self">
# 											<strong class="headline">지난 TOP 기사</strong>
# 										</a>
# 									</li>
#                         </ul>
#                     </li>
#                     <li>
#                         <a href="https://news.joins.com/reporter?cloc=joongang-article-megabottom" target="_self">
#                             <strong class="headline">기자</strong>
#                         </a>
#                     </li>
#                 </ul>
#                     <ul class="depth1">
# 									<li>
# 										<a href="https://news.joins.com/jebo?cloc=joongang-article-megaservice" target="_self">
# 											<strong class="headline">제보</strong>
# 										</a>
# ...
#                     <li><a href="https://news.joins.com/culture/art/list?cloc=joongang-article-sitemap">미술</a></li>
#                     <li><a href="https://news.joins.com/culture/classic/list?cloc=joongang-article-sitemap">클래식</a></li>
#                     <li><a href="https://news.joins.com/culture/song/list?cloc=joongang-article-sitemap">가요</a></li>
#                     <li><a href="https://news.joins.com/culture/broadcast/list?cloc=joongang-article-sitemap">방송</a></li>
#                     <li><a href="https://news.joins.com/culture/movie/list?cloc=joongang-article-sitemap">영화</a></li>
#                 </ul>
#             </div>
#             <div class="col">
#                 <strong class="mg"><a href="https://news.joins.com/sports?cloc=joongang-article-sitemap">스포츠</a></strong>
#                 <ul>
#                     <li><a href="https://news.joins.com/sports/baseball/list?cloc=joongang-article-sitemap">야구</a></li>
#                     <li><a href="https://news.joins.com/sports/worldbaseball/list?cloc=joongang-article-sitemap">해외야구</a></li>
#                     <li><a href="https://news.joins.com/sports/soccer/list?cloc=joongang-article-sitemap">축구</a></li>
#                     <li><a href="https://news.joins.com/sports/worldsoccer/list?cloc=joongang-article-sitemap">해외축구</a></li>
#                     <li><a href="https://news.joins.com/sports/basketvolley/list?cloc=joongang-article-sitemap">농구/배구</a></li>
#                 </ul>
#             </div>
#         </div>
#         <div class="row clearfx">
#             <div class="col">
#                 <strong class="mg"><a href="https://news.joins.com/lifestyle?cloc=joongang-article-sitemap">라이프 스타일</a></strong>
#                 <ul>
#                     <li><a href="https://news.joins.com/lifestyle/fashion/list?cloc=joongang-article-sitemap">패션</a></li>
#                     <li><a href="https://news.joins.com/lifestyle/taste/list?cloc=joongang-article-sitemap">맛</a></li>
#                     <li><a href="https://news.joins.com/lifestyle/luxury/list?cloc=joongang-article-sitemap">럭셔리</a></li>
#                     <li><a href="https://news.joins.com/lifestyle/beauty/list?cloc=joongang-article-sitemap">뷰티</a></li>
#                     <li><a href="https://news.joins.com/lifestyle/living/list?cloc=joongang-article-sitemap">리빙</a></li>
#                 </ul>
#             </div>
#             <div class="col">
#                 <strong class="mg"><a href="https://news.joins.com/travel?cloc=joongang-article-sitemap">여행레저</a></strong>
#                 <ul>
#                     <li><a href="https://news.joins.com/travel/domestic/list?cloc=joongang-article-sitemap">국내여행</a></li>
#                     <li><a href="https://news.joins.com/travel/abroad/list?cloc=joongang-article-sitemap">해외여행</a></li>
#                     <li><a href="https://news.joins.com/travel/news/list?cloc=joongang-article-sitemap">여행뉴스</a></li>
#                     <li><a href="https://news.joins.com/travel/week/list?cloc=joongang-article-sitemap">Week&amp;</a></li>
#                 </ul>
#             </div>
#             <div class="col">
#                 <strong class="mg"><a href="https://news.joins.com/pic?cloc=joongang-article-sitemap">포토 · 영상</a></strong>
#                 <ul>
#                     <li><a href="https://news.joins.com/pic/photogallery/list?cloc=joongang-article-sitemap">포토</a></li>
#                     <li><a href="https://news.joins.com/pic/vod/list?cloc=joongang-article-sitemap">영상</a></li>
#                 </ul>
#             </div>
#             <div class="col">
#                 <strong class="mg"><a href="https://news.joins.com/people?cloc=joongang-article-sitemap">피플</a></strong>
#                 <ul>
#                     <li><a href="https://news.joins.com/people/room/list?cloc=joongang-article-sitemap">사랑방</a></li>
#                     <li><a href="https://news.joins.com/people/personnel/list?cloc=joongang-article-sitemap">인사</a></li>
#                     <li><a href="https://news.joins.com/people/death/list?cloc=joongang-article-sitemap">부음</a></li>
#                 </ul>
#             </div>
#             <div class="col">
#                 <strong class="mg">스페셜</strong>
#                 <ul>
#                     <li><a href="https://news.joins.com/sunday?cloc=joongang-article-sitemap">중앙SUNDAY</a></li>
#                     <li><a href="https://news.joins.com/digitalspecial/list?cloc=joongang-article-sitemap">디지털스페셜</a></li>
#                     <li><a href="https://news.joins.com/nk?cloc=joongang-article-sitemap">통일무지개</a></li>
#                     <li><a href="https://news.joins.com/retirement?cloc=joongang-article-sitemap">더,오래</a></li>
#                     <li><a href="https://mgrg.joins.com/?cloc=joongang-article-sitemap" target="_blank">먼지알지</a></li>
#                     <li><a href="https://welfaretotal.joins.com/?cloc=joongang-article-sitemap" target="_blank">복지토털</a></li>
#                     <li><a href="https://news.joins.com/mm?cloc=joongang-article-sitemap">Mr.밀리터리</a></li>
#                     <li><a href="https://news.joins.com/jpod?cloc=joongang-article-sitemap">J팟</a></li>
#                 </ul>
#             </div>
#             <div class="col">
#                 <strong class="mg">서비스</strong>
#                 <ul>
#                     <li><a href="https://news.joins.com/newsletter?cloc=joongang-article-sitemap">뉴스레터</a></li>
#                     <li><a href="https://news.joins.com/issue?cloc=joongang-article-sitemap">이슈패키지</a></li>
#                     <li><a href="https://news.joins.com/trend?cloc=joongang-article-sitemap">트랜드 뉴스</a></li>
#                     <li><a href="https://news.joins.com/reporter?cloc=joongang-article-sitemap">기자</a></li>
#                     <li><a href="https://people.joins.com/?cloc=joongang-article-sitemap">인물정보</a></li>
#                     <li><a href="https://www.joins.com/Media/List.aspx?mseq=11&amp;cloc=joongang-article-sitemap">전자판</a></li>
#                 </ul>
#             </div>
#             <div class="col">
#                 <strong class="mg">독자 서비스</strong>
#                 <ul>
#                     <li><a href="https://jmembership.joins.com/?cloc=joongang-article-sitemap">중앙멤버십</a></li>
#                     <li><a href="https://www.joins.com/Apply/Subscribe.aspx?cloc=joongang-article-sitemap">구독신청</a></li>
#                     <li><a href="https://news.joins.com/jtour?cloc=joongang-article-sitemap">견학신청</a></li>
#                     <li><a href="https://news.joins.com/jebo?cloc=joongang-article-sitemap">제보</a></li>
#                     <li><a href="https://news.joins.com/brandnews?cloc=joongang-article-sitemap">보도자료</a></li>
#                     <li><a href="https://news.joins.com/customercenter?cloc=joongang-article-sitemap">고객센터</a></li>
#                 </ul>
#             </div>
#         </div>
#     </div>
# </div>
#             </div>
#         </footer>
#
#     </div>
#     <div id="loading"><img alt="" src="https://images.joins.com/ui_joongang/news/pc/common/loading_64.gif"/></div>
#     <style>
#         .article_body [class^=tag_] {
#             display: none;
#         }
#
#         .search_area .ui-datepicker-trigger {
#             margin-left: 13px;
#         }
#
#         a.disable {
#             pointer-events: none;
#             cursor: default;
#         }
#
#         .preload {
#             display: none;
#         }
#
#         .slick-track .image_area {
#             float: left;
#         }
#     </style>
#     <script src="https://static.joins.com/joongang_15re/scripts/data/menu.pc.js?20210808" type="text/javascript"></script>
#     <script id="_daytimer" src="https://static.joins.com/common/data/nowdaytime/daytimer.js?20210808" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/scripts/lib/jquery/jquery-1.11.3.min.js" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/scripts/lib/jquery/ui/jquery-ui.min.js" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/scripts/lib/jquery/jquery-migrate-1.2.1.min.js" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/scripts/lib/jquery/plugins/jquery.dotdotdot.min.js" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/scripts/lib/jquery/plugins/jquery-deparam.js" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/scripts/lib/jquery/jquery.unobtrusive-ajax.min.js" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/scripts/lib/transparency.min.js" type="text/javascript"></script>
#     <script src="https://developers.kakao.com/sdk/js/kakao.min.js" type="text/javascript"></script>
#     <script src="https://connect.facebook.net/ko_KR/all.js" type="text/javascript"></script>
#
#
#     <script src="https://platform.twitter.com/widgets.js" type="text/javascript"></script>
#     <!--[if lte IE 9]>
#         <script src="https://static.joins.com/joongang_15re/scripts/lib/html5shiv.js"></script>
#         <script src="https://static.joins.com/joongang_15re/scripts/lib/respond.min.js"></script>
#         <script src="https://static.joins.com/joongang_15re/scripts/lib/json2.js"></script>
#         <script src="https://static.joins.com/joongang_15re/scripts/lib/jquery/jquery.xdomainrequest.js"></script>
#     <![endif]-->
#     <script src="https://static.joins.com/joongang_15re/scripts/utils/jquery.utils.js?20210808" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/scripts/utils/utils.js?20210808" type="text/javascript"></script>
#     <script type="text/javascript">
#         document.domain = "joins.com";
#         utils.config({
#             'homePath': 'https://joongang.joins.com',
#             'webPcPath': 'https://news.joins.com',
#             'webMobilePath': 'https://mnews.joins.com',
#             'staticPath': 'https://static.joins.com/joongang_15re',
#             'imagePath': 'https://images.joins.com/ui_joongang/news',
#             'apiPath': 'https://apis.joins.com',
#             'irPath': 'https://ir.joins.com',
#             'pdsPath': 'https://pds.joins.com',
#             'jtbcImagePath': 'http://photo.jtbc.joins.com',
#             'jplusPath': 'http://jplus.joins.com',
#             'searchWebPath': 'https://news.joins.com/search',
#             'pageType': 'Article' || PAGE_TYPE.index,
#             'articleType': 'General' || ARTICLE_TYPE.general
#         });
#
#
#
#     </script>
#     <script src="https://static.joins.com/joongang_15re/scripts/layout.js?20210808" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/scripts/layout.header.js?20210808" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/scripts/utils/widget.js?20210808" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/scripts/lib/slick.min.js" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/scripts/init.js?20210808" type="text/javascript"></script>
# 		<script src="https://static.joins.com/joongang_15re/scripts/_res/JAddon/v1/jaddon.js?20210808" type="text/javascript"></script>
# 		<link href="https://static.joins.com/joongang_15re/scripts/_res/JAddon/v1/jaddon.css?20210808" rel="stylesheet"/>
#
#     <script src="https://static.joins.com/joongang_15re/scripts/utils/article.components.js?20210808" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/scripts/utils/poll.js?20210808" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/comment/language.js?20210808" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/comment/pc/html.js?20210808" type="text/javascript"></script>
#     <script src="https://static.joins.com/joongang_15re/comment/pc/comment.js?20210808" type="text/javascript"></script>
#     <script src="https://static.joins.com/common/ui/script/articleCounter.js?20210808" type="text/javascript"></script>
#     <script type="text/javascript">
#         if(utils.isLiveServer()) {
#             fnArticleCounterCheck('24131121', '15', '1503001', 'J', 'r');
#         }
#     </script>
#
#     <script type="text/javascript">
#         $(function() {
#             var BTN_OPTIONS = {
#                 open: {
#                     cls: 'btn_open',
#                     text: '열기'
#                 },
#                 close: {
#                     cls: 'btn_close',
#                     text: '닫기'
#                 }
#             };
#
#             $('.journalist_area').on('click', '.btn_open', function() {
#
#                 var $row = $(this).closest('.row');
#
#                 $row
#                     .nextAll()
#                     .show();
#
#                 $(this).removeClass(BTN_OPTIONS.open.cls).addClass(BTN_OPTIONS.close.cls).text(BTN_OPTIONS.close.text);
#
#                 return false;
#             }).on('click', '.btn_close', function() {
#
#                 var $row = $(this).closest('.row');
#
#                 $row
#                     .nextAll()
#                     .hide();
#
#                 $(this).removeClass(BTN_OPTIONS.close.cls).addClass(BTN_OPTIONS.open.cls).text(BTN_OPTIONS.open.text);
#                 return false;
#             });
#         });
#     </script>
# <script type="text/javascript">
#     (function (window, document, $) {
#         $(function ($) {
#             $(window).scroll(function () {
#                 winH = $("#doc").height();
#                 journalistH = $(".journalist_area").height() + 8;
#                 if ($(window).scrollTop() > $("#body").offset().top) {
#                     winbtmH = $("#doc").height() - $("#article_body").height() - $(".ad_728_90").height();
#                     var y = $("#article_body").height() - 146;
#                     if ((winH - $(window).scrollTop()) > winbtmH) {
#                         $(".share_article").css({ position: 'fixed', top: 120 + 'px' });
#                     } else { $(".share_article").css({ position: 'absolute', top: y + 'px' }); }
#                 } else { $(".share_article").css({ position: 'absolute', top: journalistH + 'px' }); }
#             });
#             $(".share_article .icon_more").click(function () {
#                 $(".share_article").toggleClass("open");
#                 $(".social_share_add").slideDown();
#             });
#             $(".share_article .icon_close").click(function () {
#                 $(".share_article").removeClass("open");
#                 $(".social_share_add").slideUp(300);
#             });
#
#             $(".share_article .icon_more").one("click", function () {
#                 $.getScript("https://static.joins.com/joongang_15re/scripts/lib/clipboard.min.js", function () {
#                     try {
#                         var clipboard = new Clipboard(".share_article .icon_url", {
#                             text: function () {
#                                 return "https://news.joins.com/article/24131121";
#                             }
#                         });
#                         clipboard.on("success", function (e) {
#                             alert("주소가 복사되었습니다.\n원하는 곳에 붙여넣기(Ctrl+V) 해주세요.");
#                         });
#                     } catch (e) {
#                         $(".share_article .icon_url").click(function () {
#                             alert("지원하지 않는 브라우저입니다.\n직접 복사해 주세요.");
#                         });
#                     }
#                 });
#             });
#         });
#     })(window, document, jQuery);
#     </script>
# <script src="https://www.gstatic.com/firebasejs/7.4.0/firebase-app.js"></script>
#         <script src="https://www.gstatic.com/firebasejs/7.4.0/firebase-messaging.js"></script>
#         <script async="" src="https://news.joins.com/lib/pwa/app.js?v=1"></script>
# <script type="text/javascript">
#         window._taboola = window._taboola || [];
#         _taboola.push({ flush: true });
#     </script>
# <script type="text/javascript">
#         $(function () {
#             $('#sub_series_recommendedArticles').show();
#         });
#     </script>
#
#
#
#
#
#
# </body></html>

# %%
# select: 하위 모든 내용들을 다 가지고 옴, div class 또는 id는 웹사이트마다 다를 수 있음 
# 여기서는 div class 명 article_body로 가지고 오는 듯
contents = soup2.select('div.article_body') 
contents
# Out:
# [<div class="article_body mg fs4" id="article_body" itemprop="articleBody">
#
#
#
#  <div class="ab_photo photo_center" style="width: 560px;">      <div class="image">                <img alt="'해적왕의 한 남자' " data-src="https://pds.joins.com/news/component/htmlphoto_mmdata/202108/19/89c298f9-521e-4322-acec-973697838d1c.jpg" data-type="article" src="https://pds.joins.com/news/component/htmlphoto_mmdata/202108/19/89c298f9-521e-4322-acec-973697838d1c.jpg"/>        <span class="mask"></span>              </div>              <p class="caption">'해적왕의 한 남자' </p>          </div>        그룹 에이티즈(ATEEZ)가 김종국의 칭찬세례에 감동했다.  <br/>  <br/>      <br/>   지난 18일 오후 카카오TV를 통해 공개된 '해적왕의 한 남자'에는 컬래버 음원 '바다 보러 갈래?'를 위해 모인 에이티즈와 김종국의 모습이 담겼다.  <br/>      <br/>   에이티즈는 대선배 김종국과 구면인 사이가 되자 은근히 자신들의 이름을 알아주길 바라는 마음을 내비쳤다. 그리곤 은근슬쩍 '김종국의 에이티즈 이름 맞히기' 게임을 시작했다.  <br/>      <br/>   김종국은 풋볼을 함께한 종호부터 같은 지역 출신인 홍중을 비롯해 우영과 민기의 이름까지 어려움없이 쉽게 맞혔다. 나머지 멤버들 또한 상의 뒷면에 새겨진 이름과 힌트를 이용해 모두 맞혔다.    <br/>      <br/>   감격한 에이티즈는 분위기 급물살을 타 전화번호까지 교환했다. 김종국은 "H.O.T 이후 멤버 전원의 이름을 외운 건 에이티즈가 처음"이라며 너스레를 떨었다. 이후 김종국이 시킨 백숙과 닭볶음탕을 먹던 아홉 남자는 새로운 컬래버 조합의 팀명을 지었다. 종호의 '씨씨(SEE SEA)' 아이디어에 흡족해하며 즉석 안무까지 맞췄다.    <br/>      <br/>   김종국은 KBS 2TV '불후의 명곡'에서 보여준 에이티즈의 '검은 고양이' 무대에 대해 "무대 하나로 끝나는 건데 준비를 너무 열심히 해준 게 고마웠고, 저렇게 할 수 있을까라는 생각에 감동했다. 에이티즈는 뭔가 다르다. 그때 잘 될 것 같다는 생각을 많이 했다"라고 말했다.    <br/>      <br/>   한편 영상 말미에는 녹음실 비하인드가 짧게 공개되며, 다음 화에 '바다 보러 갈래?'의 녹음 과정이 담길 것을 예고해 기대감을 높였다.    <br/>      <br/>   김종국과 에이티즈의 리얼리티 '해적왕의 한 남자'는 매주 수요일 오후 7시 카카오TV를 통해 선공개된다. 그 다음 월요일 오후 5시에는 1theK 공식 유튜브 채널을 통해서도 만날 수 있다.    <br/>      <br/>   황소영 기자 hwang.soyoung@joongang.co.kr  <br/>
#
#  <img height="1" id="ja_read_tracker" src="https://pds.joins.com/blank.gif" width="1"/>
#
#  <!-- 아티클 공통 : DA 250 -->
#  <div class="" id="criteo_network" style="width:250px;height:250px;float:right;clear:both;"></div>
#  <!-- 아티클 공통 : 관련기사 -->
#  <!-- //아티클 공통 : 관련기사 -->
#      </div>]

# %%
raw = ""
for title in soup.findAll("a", {"href":re.compile("https://news.joins.com/article*")}):
    article_url = title['href'] # 순서대로 url 주소 가져오기
    
    try : 
        html2 = urlopen(article_url)
        soup2 = BeautifulSoup(html.read(), 'html5lib', from_encoding = 'utf8') # draw every html tags
        contents = soup2.select('div.article_body') # select html tag 
        
        for i in contents: 
            data = str(i.findAll(text=True))
            raw = raw + data
    except Exception as e : 
        pass

print(raw)

# %%
nlp = Okt()
nouns = nlp.nouns(raw)
nouns
# Out:
# []

# %%
result = []

for i in nouns : 
    if len(i)>1: 
        result.append(i)
result
# Out:
# []

# %%
count = Counter(result)
count
# Out:
# Counter()

# %%
tag = count.most_common(3)
tag
# Out:
# []

# %%
taglist = pytagcloud.make_tags(tag, maxsize = 100)
print(taglist)
# Out:
# []

# %%
pytagcloud.create_tag_image(taglist, "testing.png", size=(1000,1000), fontname = 'korean', rectangular = False)

# %%
img = mpimg.imread("testing.png")
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-215-127084ccc65a> in <module>
# ----> 1 img = mpimg.imread("testing.png")
#       2 plt.imshow(img)
#       3 plt.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in imread(fname, format)
#    1494                     response = io.BytesIO(response.read())
#    1495                 return imread(response, format=ext)
# -> 1496     with img_open(fname) as image:
#    1497         return (_pil_png_to_float_array(image)
#    1498                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ~/opt/anaconda3/lib/python3.8/site-packages/PIL/ImageFile.py in __init__(self, fp, filename)
#     107         if isPath(fp):
#     108             # filename
# --> 109             self.fp = open(fp, "rb")
#     110             self.filename = fp
#     111             self._exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'testing.png'

# %% [markdown]
# ## Test 1차

# %% [markdown]
# 캐글 타이타닉 파일 다운로드 링크 https://www.kaggle.com/c/titanic/data

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import math
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings ; warnings.filterwarnings('ignore')

# %% [markdown]
# 1. 다운 받은 train 데이터를 아래와 같이 불러오고 index를 PassengerId로 변경하세요.
# ![문제1](문제1.jpg)

# %%
# code를 작성하세요.
t_train = pd.read_csv("/Users/user/Downloads/crawlingtest/t_train.csv")
t_train = t_train.set_index('PassengerId')
t_train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# 2. 다운 받은 test 데이터를 아래와 같이 불러오고 index를 PassengerId로 변경하세요.
# ![문제2](문제2.jpg)

# %%
# code를 작성하세요.
t_test = pd.read_csv("/Users/user/Downloads/crawlingtest/t_test.csv")
t_test = t_test.set_index('PassengerId')
t_test
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
#               Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0              330911    7.8292   NaN        Q
# 893          47.0      1      0              363272    7.0000   NaN        S
# 894          62.0      0      0              240276    9.6875   NaN        Q
# 895          27.0      0      0              315154    8.6625   NaN        S
# 896          22.0      1      1             3101298   12.2875   NaN        S
# ...           ...    ...    ...                 ...       ...   ...      ...
# 1305          NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1306         39.0      0      0            PC 17758  108.9000  C105        C
# 1307         38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308          NaN      0      0              359309    8.0500   NaN        S
# 1309          NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 10 columns]

# %% [markdown]
# 3. train 데이터를 활용해 아래와 같은 dataframe을 도출해보세요. Survived는 생존자는 1, 사망자는 0 입니다. 따라서 Survived의 mean값은
#    생존율로 볼 수 있습니다.
# ![문제3](문제3.jpg)

# %%
# code를 작성하세요.
t_train.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# 4. countplot을 사용하여 아래와 같은 그래프를 도출해보세요. Pclass의 1은 1등석, 2는 2등석, 3은 3등석입니다. 보시는대로 1등석이 다른 등석
#    보다 높은 생존율을 보입니다. y축의 count는 총 수기 때문에 Pclass 별 총 생존수와 총 사망자수로 볼 수 있습니다.
# ![문제4](문제4.jpg)

# %%
# code를 작성하세요.
plt.figure(figsize=(10,5))
sns.countplot(data=t_train, x='Pclass',  hue = 'Survived')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# 5. pivot table을 사용하여 아래와 같은 dataframe을 만들어보세요. C,Q,S는 타이타닉이 경유한 항구의 앞글자이며 승객들은 해당되는 항구에서
#    타이타닉을 탔습니다. C항구에서 탄 사람들이 높은 생존율을 보입니다.
# ![문제5](문제5.jpg)

# %%
# code를 작성하세요.
pd.pivot_table(t_train, index='Embarked', values='Survived')

# pd.pivot_table(tips, index=['level', 'smoker'], values = ['tip', 'bill'], aggfunc=['mean', 'sum','std'])
# Out:
#           Survived
# Embarked
# C         0.553571
# Q         0.389610
# S         0.336957

# %% [markdown]
# 6. Countplot을 활용하여 아래 그래프를 도출해보세요.
# ![문제6](문제6.jpg)

# %%
# code를 작성하세요.
sns.countplot(data=t_train, x='Embarked', hue='Survived')
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %% [markdown]
# 7. groupby를 사용하여 아래와 같은 Series를 만들어보세요.
# ![문제7](문제7.jpg)

# %%
# code를 작성하세요.
t_train.groupby(['Pclass'])['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %% [markdown]
# 8. AgeType이라는 컬럼을 만들어 봅시다. 15세 미만은 young, 15세 이상 30세 미만은 middle, 30세 이상은 old로 정합니다.
#    아래와 같은 dataframe을 도출해보세요.
# ![문제8](문제8.jpg)

# %%
# code를 작성하세요.
# t_train['AgeType'] = 
t_train.loc[t_train['Age']<15, 'AgeType'] = "young"
t_train.loc[(t_train['Age']>=15) & (t_train['Age']<30), 'AgeType'] = "middle"
t_train.loc[t_train['Age']>=30, 'AgeType'] = "old"
t_train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked AgeType
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S  middle
# 2                1      0          PC 17599  71.2833   C85        C     old
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  middle
# 4                1      0            113803  53.1000  C123        S     old
# 5                0      0            373450   8.0500   NaN        S     old
# ...            ...    ...               ...      ...   ...      ...     ...
# 887              0      0            211536  13.0000   NaN        S  middle
# 888              0      0            112053  30.0000   B42        S  middle
# 889              1      2        W./C. 6607  23.4500   NaN        S     NaN
# 890              0      0            111369  30.0000  C148        C  middle
# 891              0      0            370376   7.7500   NaN        Q     old
#
# [891 rows x 12 columns]

# %% [markdown]
# 9. 아래와 같은 그래프를 도출해보세요.
# ![문제9](문제9.jpg)

# %%
# code를 작성하세요.
sns.countplot(data=t_train, x='AgeType', hue='Survived')
# Out:
# <AxesSubplot:xlabel='AgeType', ylabel='count'>

# %% [markdown]
# 10. 나이를 모르는 사람과 나이가 알려진 사람을 구별하는 컬럼을 만들어 봅시다. Age에 나이가 입력되지 않은 조건은 isnull()과 notnull()을
#     사용하여 보다 편하게 전처리할 수 있습니다. 아래와 같은 dataframe을 도출해보세요.
# ![문제10](문제10.jpg)

# %%
# code를 작성하세요.
t_train.loc[(t_train['Age'].isnull()), 'AgeInfo'] = "unknown"
t_train.loc[(t_train['Age'].notnull()), 'AgeInfo'] = "known"
t_train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked AgeType  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S  middle
# 2                1      0          PC 17599  71.2833   C85        C     old
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  middle
# 4                1      0            113803  53.1000  C123        S     old
# 5                0      0            373450   8.0500   NaN        S     old
# ...            ...    ...               ...      ...   ...      ...     ...
# 887              0      0            211536  13.0000   NaN        S  middle
# 888              0      0            112053  30.0000   B42        S  middle
# 889              1      2        W./C. 6607  23.4500   NaN        S     NaN
# 890              0      0            111369  30.0000  C148        C  middle
# 891              0      0            370376   7.7500   NaN        Q     old
#
#              AgeInfo
# PassengerId
# 1              known
# 2              known
# 3              known
# 4              known
# 5              known
# ...              ...
# 887            known
# 888            known
# 889          unknown
# 890            known
# 891            known
#
# [891 rows x 13 columns]

# %% [markdown]
# 11. 아래와 같은 그래프를 도출해보세요. 나이가 기록된 사람들의 생존율이 높은 것을 알 수 있습니다.
# ![문제11](문제11.jpg)

# %%
# code를 작성하세요.
plt.figure(figsize=(10,5))
sns.countplot(data = t_train, x='AgeInfo', hue='Survived')
# Out:
# <AxesSubplot:xlabel='AgeInfo', ylabel='count'>

# %% [markdown]
# 12. Pclass 별 평균 나이의 dataframe을 구해보세요.
# ![문제12](문제12.jpg)

# %%
# code를 작성하세요.
Pclass_age = pd.pivot_table(t_train, index='Pclass', values='Age')
Pclass_age
# Out:
#               Age
# Pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620

# %%
Pclass_age_mean = Pclass_age.mean()
Pclass_age_mean
# Out:
# Age    31.083897
# dtype: float64

# %% [markdown]
# 13. Age(All) 컬럼을 만들어 보겠습니다. 나이가 기록된 사람은 같은 나이를 입력하시고 나이가 기록 안된 사람은 Pclass 별 평균 나이를
#     입력해 봅시다. 아래와 같은 dataframe을 도출해보세요.
# ![문제13](문제13.jpg)

# %%
# code를 작성하세요.
t_train.loc[t_train['Age'].notnull(), 'Age(All)'] = t_train['Age']
t_train.loc[(t_train['Age'].isnull()) & (t_train['Pclass'] == 1), 'Age(All)'] = 38.233441
t_train.loc[(t_train['Age'].isnull()) & (t_train['Pclass'] == 2), 'Age(All)'] = 29.877630
t_train.loc[(t_train['Age'].isnull()) & (t_train['Pclass'] == 3), 'Age(All)'] = 25.140620

t_train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked AgeType  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S  middle
# 2                1      0          PC 17599  71.2833   C85        C     old
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  middle
# 4                1      0            113803  53.1000  C123        S     old
# 5                0      0            373450   8.0500   NaN        S     old
# ...            ...    ...               ...      ...   ...      ...     ...
# 887              0      0            211536  13.0000   NaN        S  middle
# 888              0      0            112053  30.0000   B42        S  middle
# 889              1      2        W./C. 6607  23.4500   NaN        S     NaN
# 890              0      0            111369  30.0000  C148        C  middle
# 891              0      0            370376   7.7500   NaN        Q     old
#
#              AgeInfo  Age(All)
# PassengerId
# 1              known  22.00000
# 2              known  38.00000
# 3              known  26.00000
# 4              known  35.00000
# 5              known  35.00000
# ...              ...       ...
# 887            known  27.00000
# 888            known  19.00000
# 889          unknown  25.14062
# 890            known  26.00000
# 891            known  32.00000
#
# [891 rows x 14 columns]

# %% [markdown]
# 14. 타이타닉 승객 중 혼자 탄 사람을 나타내는 single 컬럼을 만들어 봅시다. SibSp는 배우자와 자녀의 총 수를 나타내며 Parch는 부모의 수를
#     뜻합니다. SibSp와 Parch가 모두 0인 사람이 타이타닉에 혼자 승선한 승객입니다. 혼자 승선했을 경우 1이라 입력하고 아닐 경우 0으로
#     입력합시다. 아래와 같은 dataframe을 도출해 보세요.
#
# ![문제14](문제14.jpg)

# %%
# code를 작성하세요.
t_train.loc[(t_train['SibSp']==0) & (t_train['Parch']==0), 'Single'] = 1
t_train.loc[(t_train['SibSp']!=0) | (t_train['Parch']!=0), 'Single'] = 0
t_train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked AgeType  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S  middle
# 2                1      0          PC 17599  71.2833   C85        C     old
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  middle
# 4                1      0            113803  53.1000  C123        S     old
# 5                0      0            373450   8.0500   NaN        S     old
# ...            ...    ...               ...      ...   ...      ...     ...
# 887              0      0            211536  13.0000   NaN        S  middle
# 888              0      0            112053  30.0000   B42        S  middle
# 889              1      2        W./C. 6607  23.4500   NaN        S     NaN
# 890              0      0            111369  30.0000  C148        C  middle
# 891              0      0            370376   7.7500   NaN        Q     old
#
#              AgeInfo  Age(All)  Single
# PassengerId
# 1              known  22.00000     0.0
# 2              known  38.00000     0.0
# 3              known  26.00000     1.0
# 4              known  35.00000     0.0
# 5              known  35.00000     1.0
# ...              ...       ...     ...
# 887            known  27.00000     1.0
# 888            known  19.00000     1.0
# 889          unknown  25.14062     0.0
# 890            known  26.00000     1.0
# 891            known  32.00000     1.0
#
# [891 rows x 15 columns]

# %% [markdown]
# 15. 아래와 같은 그래프를 도출해보세요. 혼자 승선한 승객의 사망율이 높은 것을 알 수 있습니다.
# ![문제15](문제15.jpg)

# %%
# code를 작성하세요.
plt.figure(figsize=(10,5))
sns.countplot(data=t_train, x='Single', hue='Survived')
# Out:
# <AxesSubplot:xlabel='Single', ylabel='count'>

# %% [markdown]
# 16. SibSp와 Parch을 합친 총 가족수 컬럼을 만들어 봅시다. 컬럼 이름은 Family로 하겠습니다. SibSp + Parch + 1을 하여 승객 본인도 포함시켜
#     총 수를 입력합시다. pivot table을 활용하여 아래와 같은 dataframe을 도출해보세요.
# ![문제16](문제16.jpg)

# %%
# code를 작성하세요.
t_train['Family'] = t_train['SibSp'] + t_train['Parch'] + 1
t_train_family = pd.pivot_table(t_train, index='Family', values='Survived')
t_train_family
# Out:
#         Survived
# Family
# 1       0.303538
# 2       0.552795
# 3       0.578431
# 4       0.724138
# 5       0.200000
# 6       0.136364
# 7       0.333333
# 8       0.000000
# 11      0.000000

# %% [markdown]
# 17. 아래와 같은 그래프를 도출해보세요. family 수는 2~4 사이일 때 가장 생존율이 높은 것으로 보입니다.
# ![문제17](문제17.jpg)

# %%
# code를 작성하세요.
plt.figure(figsize=(10,5))
sns.countplot(data=t_train, x='Family', hue = 'Survived')
# Out:
# <AxesSubplot:xlabel='Family', ylabel='count'>

# %% [markdown]
# 18. Family 컬럼을 참고하여 수자의 크기에 따라 single, small, big으로 분류하는 FamilySize 컬럼을 만들어 봅시다. Family가 1일 때는 single,
#     1보다 크고 5보다 작을 땐 small, 5이상일 땐 big을 입력합니다. pivot table을 활용하여 아래 dataframe을 도출해 보세요.
# ![문제18](문제18.jpg)

# %%
t_train.loc[(t_train['Family']==1), 'FamilySize'] = 'single'
t_train.loc[(t_train['Family']>1) & (t_train['Family']<5), 'FamilySize'] = 'small'
t_train.loc[(t_train['Family']>=5), 'FamilySize'] = 'big'

pd.pivot_table(t_train, index='FamilySize', values = 'Survived')
# Out:
#             Survived
# FamilySize
# big         0.161290
# single      0.303538
# small       0.578767

# %% [markdown]
# 19. 아래와 같은 그래프를 도출해보세요.
# ![문제19](문제19.jpg)

# %%
# code를 작성하세요.
plt.figure(figsize=(10,5))
sns.countplot(data = t_train, x='FamilySize', hue = 'Survived')
# Out:
# <AxesSubplot:xlabel='FamilySize', ylabel='count'>

# %% [markdown]
# 20. pivot table을 활용하여 아래와 같은 dataframe을 만들어 보세요. 여성이 매우 높은 생존율을 보이는 걸 알 수 있습니다.
# ![문제20](문제20.jpg)

# %%
# code를 작성하세요.
t_train_sex = pd.pivot_table(t_train, index='Sex', values='Survived')
t_train_sex
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [markdown]
# 21. 아래와 같은 그래프를 도출해보세요.
# ![문제21](문제21.jpg)

# %%
# code를 작성하세요.
plt.figure(figsize=(10,5))
sns.countplot(data=t_train, x='Sex', hue='Survived')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# 22. Sex 컬럼의 male과 female은 머신러닝 학습 데이터로는 적합하지 않습니다. 적합하도록 새로운 Sex_number라는 새로운 컬럼을 만들어 봅시다.
#     male은 0, female은 1로 입력합시다. 아래와 같은 dataframe을 도출해 보세요.
# ![문제22](문제22.jpg)

# %%
# code를 작성하세요.
t_train.loc[t_train['Sex'] == 'male', 'Sex_number'] = 0
t_train.loc[t_train['Sex'] == 'female', 'Sex_number'] = 1

t_train[['Sex', 'Sex_number']]
# Out:
#                 Sex  Sex_number
# PassengerId
# 1              male         0.0
# 2            female         1.0
# 3            female         1.0
# 4            female         1.0
# 5              male         0.0
# ...             ...         ...
# 887            male         0.0
# 888          female         1.0
# 889          female         1.0
# 890            male         0.0
# 891            male         0.0
#
# [891 rows x 2 columns]

# %% [markdown]
# 23. 남성과 여성의 생존율 차이가 극명합니다. 좀더 디테일하게 확인해 봅시다. Titles 컬럼을 만들어 Mr, Miss, Mrs, Master로 분류해 봅시다.
#     Master는 당시에 결혼하지 않은 남성에게 붙이는 호칭이었습니다. .str.contains을 사용하면 문자열에서 특정 문자열이 포함 유무를 확인
#     할 수 있으니 사용하여 새로운 컬럼을 만들어 봅시다. 아래와 같은 dataframe을 도출해 보세요.
# ![문제23](문제23.jpg)

# %%
# code를 작성하세요. tips[tips['sex'].str.contains('ale')]
t_train.loc[t_train['Name'].str.contains('Mr'), 'Titles'] = 'Mr'
t_train.loc[t_train['Name'].str.contains('Mrs'), 'Titles'] = 'Mrs'
t_train.loc[t_train['Name'].str.contains('Miss'), 'Titles'] = 'Miss'
t_train.loc[t_train['Name'].str.contains('Master'), 'Titles'] = 'Master'
t_train.loc[t_train['Name'].isnull(), 'Titles'] = np.nan

t_train[['Name', 'Titles']]
# Out:
#                                                           Name Titles
# PassengerId
# 1                                      Braund, Mr. Owen Harris     Mr
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    Mrs
# 3                                       Heikkinen, Miss. Laina   Miss
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    Mrs
# 5                                     Allen, Mr. William Henry     Mr
# ...                                                        ...    ...
# 887                                      Montvila, Rev. Juozas    NaN
# 888                               Graham, Miss. Margaret Edith   Miss
# 889                   Johnston, Miss. Catherine Helen "Carrie"   Miss
# 890                                      Behr, Mr. Karl Howell     Mr
# 891                                        Dooley, Mr. Patrick     Mr
#
# [891 rows x 2 columns]

# %% [markdown]
# 24. 아래와 같은 그래프를 작성해보세요. 남성 중에선 Mr보다 Master의 생존율이 높게 나옵니다.
# ![문제24](문제24.jpg)

# %%
# code를 작성하세요.
plt.figure(figsize=(10,5))
sns.countplot(data=t_train, x='Titles', hue='Survived')
# Out:
# <AxesSubplot:xlabel='Titles', ylabel='count'>

# %% [markdown]
# ## 수고하셨습니다!
